# %% [markdown]
# <a href="https://colab.research.google.com/github/relew/matchPrediction/blob/master/levi_draw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import pickle

# importing the models
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBRegressor
from sklearn.metrics import confusion_matrix
import seaborn as sns
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import accuracy_score


# addition predifined 'functions' for splitting the data and evaluating the model
from sklearn.inspection import permutation_importance
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import RandomizedSearchCV

import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', 100)

import xgboost as xgb
xgb_model = xgb.XGBClassifier(objective="binary:logistic", random_state=42)


from xgboost import XGBClassifier

# %% [markdown]
# # Support functions

# %%
class match_support_functions():
        
    def categorical_to_numerical_convert(self,df,cat_columns):

        for column in cat_columns:
            one_hot = pd.get_dummies(df[column])
            # Drop column as it is now encoded
            df = df.drop(column,axis = 1)
            # Join the encoded df
            df = df.join(one_hot)

        return df

    def IQR_outlier_treatment(self,df, datacolumn, V1 , V3):
        
        print(datacolumn,V1,V3)

        Q1,Q3 = np.percentile(df[datacolumn] , [V1,V3])
        IQR = Q3 - Q1
        lower_range = Q1 - (1.5 * IQR)
        upper_range = Q3 + (1.5 * IQR)

        #print(f'{datacolumn} minimum range:',lower_range)
        #print(f'{datacolumn} maximum range:',upper_range) 
        df = df[(df[datacolumn] > lower_range) & (df[datacolumn] < upper_range)]
        
        return df
        
    def get_top_correlation(self,df):
        cor = df.corr().abs()
        cor2 = cor.unstack()
        cor3 = cor2.sort_values(kind="quicksort", ascending = False)

        return pd.DataFrame(cor3)

    def evaluate_prediction(self,y_prediction,y_val):
        
        mse = mean_squared_error(y_val, y_prediction)
        rmse = mean_squared_error(y_val, y_prediction, squared=False)
        rx = r2_score(y_val, y_prediction)
        print('model mean squared error:',mse)
        print('model root mean squared error:',rmse)
        print('model R2:',rx)


    def try_models(self,model_type,X_train,y_train,X_val,y_val):
        model = model_type
        model.fit(X_train, y_train)
        print('='*20)
        print(f'{model_type}')
        print(f'accuracy of train set: {model.score(X_train, y_train)}')
        print(f'accuracy of val set: {model.score(X_val, y_val)}')
        y_prediction = model.predict(X_val)
        self.evaluate_prediction(y_prediction,y_val)
        
        return model

# %% [markdown]
# # Script starts here

# %%
#df = pd.read_csv("match_data.csv")
#df.head()

# %%
url = 'http://dataevents.hu/202303/filedataevents/competition_table.xlsx'
df = pd.read_excel(url)

# %% [markdown]
# # Feature Engineering

# %%
df["draw_expected"] = np.where((df["odds_draw"] < df["odds_home_team_win"]) & 
                                   (df["odds_draw"] < df["odds_away_team_win"]),1,0)

# %%
df['home_win_prob'] = np.where( 1/df['odds_home_team_win'] > 1 ,1 ,1/df['odds_home_team_win'])
df['draw_prob'] = np.where( 1/df['odds_draw'] > 1 ,1 ,1/df['odds_draw'])

# %% [markdown]
# # Added metrics

# %%
# good 67.42
df["home_team_roll4_points_diff"] = df["home_team_point_roll4_sum"]-df["home_team_expected_point_roll4_sum"]
df["away_team_roll4_points_diff"] = df["away_team_point_roll4_sum"]-df["away_team_expected_point_roll4_sum"]
# good 67.46
df["home_team_roll1_points_diff"] = df["home_team_point_roll1_sum"]-df["home_team_expected_point_roll1_sum"]
df["away_team_roll1_points_diff"] = df["home_team_point_roll1_sum"]-df["home_team_expected_point_roll1_sum"]

# extra
df["home_team_all_points_diff"] = df["home_team_point_mean"]-df["home_team_expected_point_mean"]
df["away_team_all_points_diff"] = df["away_team_point_mean"]-df["away_team_expected_point_mean"]
df["home_s_p1"] = np.where(df["home_team_match_nr"]<19,1,0)
df["home_s_p2"] = np.where(df["home_team_match_nr"]>=19,1,0)

df["away_s_p1"] = np.where(df["away_team_match_nr"]<19,1,0)
df["away_s_p2"] = np.where(df["away_team_match_nr"]>=19,1,0)

# %% [markdown]
# # sample prepare

# %%
### Train

data = df.copy()

data_y1= data[data['draw_flag']==1].reset_index(drop=True)
data_y0= data[data['draw_flag']==0].reset_index(drop=True)

#selectiong train features(X_train) and train targets(y_train)
# train_feature = ['div_season_home_acc','home_win_prob',
#                  'home_team_match_nr','home_team_goal_roll4_sum','home_team_opponents_goal_roll4_sum',
#                  'home_team_point_roll4_sum','home_team_expected_point_roll4_sum',
#                  'home_team_goal_roll1_sum','home_team_opponents_goal_roll1_sum',
#                  'home_team_point_roll1_sum','home_team_expected_point_roll1_sum',
#                  'away_team_match_nr','away_team_goal_roll4_sum','away_team_opponents_goal_roll4_sum',
#                  'away_team_point_roll4_sum','away_team_expected_point_roll4_sum',
#                  'away_team_goal_roll1_sum','away_team_opponents_goal_roll1_sum',
#                  'away_team_point_roll1_sum','away_team_expected_point_roll1_sum']


train_feature = ['home_win_prob',
                 'home_team_opponents_goal_roll4_sum',
                 'home_team_point_roll4_sum','home_team_expected_point_roll4_sum',
                 'away_team_goal_roll4_sum','away_team_opponents_goal_roll4_sum',
                 'away_team_point_roll4_sum','away_team_expected_point_roll4_sum',
                 'home_team_roll4_points_diff','away_team_roll4_points_diff',
                 'home_team_roll1_points_diff','away_team_roll1_points_diff',
                 'home_s_p1','home_s_p2',
                 'away_s_p1','away_s_p2']

train_target = 'draw_flag'

### Train
data_to_train = pd.concat([data_y1[0:11000],data_y0[0:11000]], ignore_index=True)
X_train = data_to_train[train_feature].values
y_train = data_to_train[train_target].values

### Test
data_to_test = pd.concat([data_y1[11000:16000],data_y0[11000:16000]], ignore_index=True)
X_test = data_to_test[train_feature].values
y_test = data_to_test[train_target].values

support_functions = match_support_functions()

# %%
all_cols = df.columns.tolist()
all_cols.remove('match_id')
all_cols.remove('season')
all_cols.remove('div')
all_cols.remove('home_win_flag')
all_cols.remove('draw_flag')
all_cols.remove('away_win_flag')
all_cols.remove('draw_expected')

# %%
train_feature = all_cols

best_features = {}
auc_abs_max = 0
test_accuracy_abs_max = 0


for i in range(len(train_feature)-1):
    
    auc_max = 0

    for x in data_to_test[train_feature].columns:
        train_feature_x = [n for n in train_feature if n != x]


        X_train = data_to_train[train_feature_x].values
        y_train = data_to_train[train_target].values

        ### Test
        X_test = data_to_test[train_feature_x].values
        y_test = data_to_test[train_target].values

        print("******  ",x,"  ********")
        model = GaussianNB().fit(X_train,y_train)
        accuracy = model.score(X_test, y_test)
        y_prediction = model.predict_proba(X_test)[:,1]
        auc = roc_auc_score(y_test ,y_prediction )
        print("auc:",auc)
        
        if auc > auc_max:

            auc_max = auc
            auc_list = []
            auc_list.append(x)
            auc_list.append(auc)
    
        if auc > auc_abs_max:
        
            auc_abs_max = auc
            best_features["best_auc"] = train_feature_x
            
        if accuracy > test_accuracy_abs_max:
        
            test_accuracy_abs_max = accuracy
            best_features["best_acc"] = train_feature_x
    
    train_feature.remove(auc_list[0])
# Out:
# A streamkimeneten csak az utolsó 5000 sor látható.
# ******   away_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.8034256
# ******   away_team_red_card_roll4_sum   ********
# auc: 0.8040786799999999
# ******   away_team_opponents_red_card_roll4_sum   ********
# auc: 0.8042003199999999
# ******   away_team_point_roll2_sum   ********
# auc: 0.8046659599999999
# ******   away_team_expected_point_roll1_sum   ********
# auc: 0.8044938
# ******   away_team_expected_point_roll2_sum   ********
# auc: 0.80452676
# ******   away_team_expected_point_roll3_sum   ********
# auc: 0.80454624
# ******   away_team_expected_point_roll4_sum   ********
# auc: 0.8044975600000001
# ******   away_team_point_mean   ********
# auc: 0.80392072
# ******   away_team_expected_point_mean   ********
# auc: 0.80314356
# ******   home_team_all_points_diff   ********
# auc: 0.8005344799999998
# ******   away_team_all_points_diff   ********
# auc: 0.80391336
# ******   home_s_p1   ********
# auc: 0.8046205599999999
# ******   home_s_p2   ********
# auc: 0.8046205599999999
# ******   away_s_p1   ********
# auc: 0.8046308
# ******   away_s_p2   ********
# auc: 0.8046308
# ******   odds_home_team_win   ********
# auc: 0.8034092800000001
# ******   home_team_match_nr   ********
# auc: 0.8045741599999999
# ******   home_team_opponents_goal_roll3_sum   ********
# auc: 0.8045209600000001
# ******   home_team_opponents_shot_roll2_sum   ********
# auc: 0.804339
# ******   home_team_shot_on_target_roll4_sum   ********
# auc: 0.80051776
# ******   home_team_opponents_shot_on_target_roll3_sum   ********
# auc: 0.80088084
# ******   home_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.7997245599999999
# ******   home_team_corner_roll3_sum   ********
# auc: 0.80428908
# ******   home_team_corner_roll4_sum   ********
# auc: 0.8034542800000001
# ******   home_team_opponents_corner_roll1_sum   ********
# auc: 0.8042314
# ******   home_team_opponents_corner_roll2_sum   ********
# auc: 0.80395112
# ******   home_team_opponents_corner_roll3_sum   ********
# auc: 0.80365252
# ******   home_team_opponents_corner_roll4_sum   ********
# auc: 0.80318612
# ******   home_team_yellow_card_roll3_sum   ********
# auc: 0.8030250800000001
# ******   home_team_yellow_card_roll4_sum   ********
# auc: 0.80251688
# ******   home_team_opponents_yellow_card_roll1_sum   ********
# auc: 0.8041355599999999
# ******   home_team_opponents_yellow_card_roll2_sum   ********
# auc: 0.8040176
# ******   home_team_opponents_yellow_card_roll3_sum   ********
# auc: 0.8031603999999999
# ******   home_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.8029145999999999
# ******   home_team_red_card_roll2_sum   ********
# auc: 0.8047380000000001
# ******   home_team_opponents_red_card_roll3_sum   ********
# auc: 0.80397276
# ******   odds_home_team_draw_roll2_mean   ********
# auc: 0.79847756
# ******   odds_home_team_defeat_roll2_mean   ********
# auc: 0.79933436
# ******   home_team_point_mean   ********
# auc: 0.80331892
# ******   away_team_match_nr   ********
# auc: 0.8046308
# ******   away_team_goal_roll1_sum   ********
# auc: 0.8046702400000001
# ******   away_team_goal_roll2_sum   ********
# auc: 0.8046423599999999
# ******   away_team_goal_roll3_sum   ********
# auc: 0.8046018
# ******   away_team_goal_roll4_sum   ********
# auc: 0.8045651199999999
# ******   away_team_shot_roll1_sum   ********
# auc: 0.8044356400000001
# ******   away_team_shot_roll2_sum   ********
# auc: 0.8044407200000001
# ******   away_team_shot_roll3_sum   ********
# auc: 0.804204
# ******   away_team_opponents_shot_roll1_sum   ********
# auc: 0.8046208399999999
# ******   away_team_opponents_shot_roll2_sum   ********
# auc: 0.80455768
# ******   away_team_opponents_shot_roll3_sum   ********
# auc: 0.8043578400000002
# ******   away_team_opponents_shot_roll4_sum   ********
# auc: 0.8044226
# ******   away_team_shot_on_target_roll1_sum   ********
# auc: 0.8044439200000001
# ******   away_team_shot_on_target_roll3_sum   ********
# auc: 0.8033480000000001
# ******   away_team_shot_on_target_roll4_sum   ********
# auc: 0.8020075599999998
# ******   away_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.7964821200000001
# ******   away_team_fault_roll1_sum   ********
# auc: 0.80425836
# ******   away_team_corner_roll1_sum   ********
# auc: 0.8044906000000001
# ******   away_team_corner_roll2_sum   ********
# auc: 0.803997
# ******   away_team_corner_roll3_sum   ********
# auc: 0.8033283999999999
# ******   away_team_corner_roll4_sum   ********
# auc: 0.80277972
# ******   away_team_opponents_corner_roll1_sum   ********
# auc: 0.80464468
# ******   away_team_opponents_corner_roll2_sum   ********
# auc: 0.8042976000000001
# ******   away_team_opponents_corner_roll3_sum   ********
# auc: 0.8040709199999999
# ******   away_team_opponents_corner_roll4_sum   ********
# auc: 0.80340784
# ******   away_team_yelllow_card_roll2_sum   ********
# auc: 0.8042080399999999
# ******   away_team_yelllow_card_roll3_sum   ********
# auc: 0.80412764
# ******   away_team_yelllow_card_roll4_sum   ********
# auc: 0.80399768
# ******   away_team_opponents_yellow_card_roll2_sum   ********
# auc: 0.8046060800000001
# ******   away_team_opponents_yellow_card_roll3_sum   ********
# auc: 0.80432556
# ******   away_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.80349996
# ******   away_team_red_card_roll4_sum   ********
# auc: 0.8041389599999998
# ******   away_team_opponents_red_card_roll4_sum   ********
# auc: 0.8042743600000001
# ******   away_team_point_roll2_sum   ********
# auc: 0.80473316
# ******   away_team_expected_point_roll1_sum   ********
# auc: 0.8045429199999999
# ******   away_team_expected_point_roll2_sum   ********
# auc: 0.8046036400000001
# ******   away_team_expected_point_roll3_sum   ********
# auc: 0.8046238
# ******   away_team_expected_point_roll4_sum   ********
# auc: 0.80456584
# ******   away_team_point_mean   ********
# auc: 0.80399544
# ******   away_team_expected_point_mean   ********
# auc: 0.80322904
# ******   home_team_all_points_diff   ********
# auc: 0.8005387599999999
# ******   away_team_all_points_diff   ********
# auc: 0.8039901199999999
# ******   home_s_p1   ********
# auc: 0.8046828800000001
# ******   home_s_p2   ********
# auc: 0.8046828800000001
# ******   away_s_p1   ********
# auc: 0.8046976400000001
# ******   away_s_p2   ********
# auc: 0.8046976400000001
# ******   odds_home_team_win   ********
# auc: 0.80346296
# ******   home_team_match_nr   ********
# auc: 0.80464176
# ******   home_team_opponents_goal_roll3_sum   ********
# auc: 0.8046364399999999
# ******   home_team_opponents_shot_roll2_sum   ********
# auc: 0.8045994
# ******   home_team_shot_on_target_roll4_sum   ********
# auc: 0.8010830800000001
# ******   home_team_opponents_shot_on_target_roll3_sum   ********
# auc: 0.8006614400000001
# ******   home_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.7995196800000001
# ******   home_team_corner_roll3_sum   ********
# auc: 0.8044615999999999
# ******   home_team_corner_roll4_sum   ********
# auc: 0.80362056
# ******   home_team_opponents_corner_roll1_sum   ********
# auc: 0.8042405999999999
# ******   home_team_opponents_corner_roll2_sum   ********
# auc: 0.8039639599999999
# ******   home_team_opponents_corner_roll3_sum   ********
# auc: 0.80368348
# ******   home_team_opponents_corner_roll4_sum   ********
# auc: 0.803228
# ******   home_team_yellow_card_roll3_sum   ********
# auc: 0.8035603599999999
# ******   home_team_yellow_card_roll4_sum   ********
# auc: 0.8031086
# ******   home_team_opponents_yellow_card_roll1_sum   ********
# auc: 0.80425148
# ******   home_team_opponents_yellow_card_roll2_sum   ********
# auc: 0.80414828
# ******   home_team_opponents_yellow_card_roll3_sum   ********
# auc: 0.8033760800000003
# ******   home_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.8031336
# ******   home_team_opponents_red_card_roll3_sum   ********
# auc: 0.8038022399999999
# ******   odds_home_team_draw_roll2_mean   ********
# auc: 0.7983922
# ******   odds_home_team_defeat_roll2_mean   ********
# auc: 0.79951992
# ******   home_team_point_mean   ********
# auc: 0.80343736
# ******   away_team_match_nr   ********
# auc: 0.80469296
# ******   away_team_goal_roll1_sum   ********
# auc: 0.80474408
# ******   away_team_goal_roll2_sum   ********
# auc: 0.8047147200000001
# ******   away_team_goal_roll3_sum   ********
# auc: 0.8046686
# ******   away_team_goal_roll4_sum   ********
# auc: 0.8046224799999999
# ******   away_team_shot_roll1_sum   ********
# auc: 0.80450976
# ******   away_team_shot_roll2_sum   ********
# auc: 0.8045181600000001
# ******   away_team_shot_roll3_sum   ********
# auc: 0.8043116
# ******   away_team_opponents_shot_roll1_sum   ********
# auc: 0.8046711599999999
# ******   away_team_opponents_shot_roll2_sum   ********
# auc: 0.80461692
# ******   away_team_opponents_shot_roll3_sum   ********
# auc: 0.80441716
# ******   away_team_opponents_shot_roll4_sum   ********
# auc: 0.8044642800000001
# ******   away_team_shot_on_target_roll1_sum   ********
# auc: 0.8044471200000001
# ******   away_team_shot_on_target_roll3_sum   ********
# auc: 0.8034124
# ******   away_team_shot_on_target_roll4_sum   ********
# auc: 0.8021016400000001
# ******   away_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.7968869199999999
# ******   away_team_fault_roll1_sum   ********
# auc: 0.8042740799999999
# ******   away_team_corner_roll1_sum   ********
# auc: 0.8045203199999998
# ******   away_team_corner_roll2_sum   ********
# auc: 0.80406128
# ******   away_team_corner_roll3_sum   ********
# auc: 0.8033934800000001
# ******   away_team_corner_roll4_sum   ********
# auc: 0.8028398
# ******   away_team_opponents_corner_roll1_sum   ********
# auc: 0.80473856
# ******   away_team_opponents_corner_roll2_sum   ********
# auc: 0.80437332
# ******   away_team_opponents_corner_roll3_sum   ********
# auc: 0.8041936399999999
# ******   away_team_opponents_corner_roll4_sum   ********
# auc: 0.80353472
# ******   away_team_yelllow_card_roll2_sum   ********
# auc: 0.8043262
# ******   away_team_yelllow_card_roll3_sum   ********
# auc: 0.80432144
# ******   away_team_yelllow_card_roll4_sum   ********
# auc: 0.80420384
# ******   away_team_opponents_yellow_card_roll2_sum   ********
# auc: 0.8047984
# ******   away_team_opponents_yellow_card_roll3_sum   ********
# auc: 0.8045665199999998
# ******   away_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.8037521999999999
# ******   away_team_red_card_roll4_sum   ********
# auc: 0.80412608
# ******   away_team_opponents_red_card_roll4_sum   ********
# auc: 0.80432064
# ******   away_team_point_roll2_sum   ********
# auc: 0.80479904
# ******   away_team_expected_point_roll1_sum   ********
# auc: 0.8045775200000002
# ******   away_team_expected_point_roll2_sum   ********
# auc: 0.8046576799999998
# ******   away_team_expected_point_roll3_sum   ********
# auc: 0.8046701999999999
# ******   away_team_expected_point_roll4_sum   ********
# auc: 0.8046196400000001
# ******   away_team_point_mean   ********
# auc: 0.80403796
# ******   away_team_expected_point_mean   ********
# auc: 0.80327704
# ******   home_team_all_points_diff   ********
# auc: 0.8004281200000001
# ******   away_team_all_points_diff   ********
# auc: 0.8040392799999999
# ******   home_s_p1   ********
# auc: 0.80473956
# ******   home_s_p2   ********
# auc: 0.80473956
# ******   away_s_p1   ********
# auc: 0.8047444400000001
# ******   away_s_p2   ********
# auc: 0.8047444400000001
# ******   odds_home_team_win   ********
# auc: 0.80356904
# ******   home_team_match_nr   ********
# auc: 0.80469616
# ******   home_team_opponents_goal_roll3_sum   ********
# auc: 0.80469956
# ******   home_team_opponents_shot_roll2_sum   ********
# auc: 0.8046616400000001
# ******   home_team_shot_on_target_roll4_sum   ********
# auc: 0.80114044
# ******   home_team_opponents_shot_on_target_roll3_sum   ********
# auc: 0.80071756
# ******   home_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.79957072
# ******   home_team_corner_roll3_sum   ********
# auc: 0.8045112400000001
# ******   home_team_corner_roll4_sum   ********
# auc: 0.8036834399999999
# ******   home_team_opponents_corner_roll1_sum   ********
# auc: 0.8042924400000001
# ******   home_team_opponents_corner_roll2_sum   ********
# auc: 0.8040214000000001
# ******   home_team_opponents_corner_roll3_sum   ********
# auc: 0.80375568
# ******   home_team_opponents_corner_roll4_sum   ********
# auc: 0.8032894000000002
# ******   home_team_yellow_card_roll3_sum   ********
# auc: 0.8036274000000001
# ******   home_team_yellow_card_roll4_sum   ********
# auc: 0.8031791599999999
# ******   home_team_opponents_yellow_card_roll1_sum   ********
# auc: 0.80431964
# ******   home_team_opponents_yellow_card_roll2_sum   ********
# auc: 0.80420932
# ******   home_team_opponents_yellow_card_roll3_sum   ********
# auc: 0.80341676
# ******   home_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.80320384
# ******   home_team_opponents_red_card_roll3_sum   ********
# auc: 0.803854
# ******   odds_home_team_draw_roll2_mean   ********
# auc: 0.7984239999999999
# ******   odds_home_team_defeat_roll2_mean   ********
# auc: 0.7996156799999999
# ******   home_team_point_mean   ********
# auc: 0.8034821199999999
# ******   away_team_match_nr   ********
# auc: 0.80475032
# ******   away_team_goal_roll1_sum   ********
# auc: 0.80476812
# ******   away_team_goal_roll2_sum   ********
# auc: 0.8046946000000001
# ******   away_team_goal_roll3_sum   ********
# auc: 0.8046747600000002
# ******   away_team_goal_roll4_sum   ********
# auc: 0.80463744
# ******   away_team_shot_roll1_sum   ********
# auc: 0.8045615999999999
# ******   away_team_shot_roll2_sum   ********
# auc: 0.8045644
# ******   away_team_shot_roll3_sum   ********
# auc: 0.8043451599999999
# ******   away_team_opponents_shot_roll1_sum   ********
# auc: 0.80474
# ******   away_team_opponents_shot_roll2_sum   ********
# auc: 0.8046802000000001
# ******   away_team_opponents_shot_roll3_sum   ********
# auc: 0.8044819999999999
# ******   away_team_opponents_shot_roll4_sum   ********
# auc: 0.8045410000000001
# ******   away_team_shot_on_target_roll1_sum   ********
# auc: 0.80461216
# ******   away_team_shot_on_target_roll3_sum   ********
# auc: 0.80363908
# ******   away_team_shot_on_target_roll4_sum   ********
# auc: 0.80237124
# ******   away_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.7967586799999999
# ******   away_team_fault_roll1_sum   ********
# auc: 0.8043061999999999
# ******   away_team_corner_roll1_sum   ********
# auc: 0.804572
# ******   away_team_corner_roll2_sum   ********
# auc: 0.80411012
# ******   away_team_corner_roll3_sum   ********
# auc: 0.8034384400000001
# ******   away_team_corner_roll4_sum   ********
# auc: 0.80292972
# ******   away_team_opponents_corner_roll1_sum   ********
# auc: 0.80479268
# ******   away_team_opponents_corner_roll2_sum   ********
# auc: 0.8044213599999999
# ******   away_team_opponents_corner_roll3_sum   ********
# auc: 0.80423676
# ******   away_team_opponents_corner_roll4_sum   ********
# auc: 0.80358856
# ******   away_team_yelllow_card_roll2_sum   ********
# auc: 0.80440672
# ******   away_team_yelllow_card_roll3_sum   ********
# auc: 0.80438776
# ******   away_team_yelllow_card_roll4_sum   ********
# auc: 0.8042783599999999
# ******   away_team_opponents_yellow_card_roll2_sum   ********
# auc: 0.80484312
# ******   away_team_opponents_yellow_card_roll3_sum   ********
# auc: 0.8046208400000001
# ******   away_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.80383156
# ******   away_team_red_card_roll4_sum   ********
# auc: 0.8041413199999999
# ******   away_team_opponents_red_card_roll4_sum   ********
# auc: 0.80439684
# ******   away_team_expected_point_roll1_sum   ********
# auc: 0.80466032
# ******   away_team_expected_point_roll2_sum   ********
# auc: 0.80470368
# ******   away_team_expected_point_roll3_sum   ********
# auc: 0.80470944
# ******   away_team_expected_point_roll4_sum   ********
# auc: 0.8046662800000001
# ******   away_team_point_mean   ********
# auc: 0.8040415599999999
# ******   away_team_expected_point_mean   ********
# auc: 0.80323216
# ******   home_team_all_points_diff   ********
# auc: 0.8005176
# ******   away_team_all_points_diff   ********
# auc: 0.80407064
# ******   home_s_p1   ********
# auc: 0.80479896
# ******   home_s_p2   ********
# auc: 0.80479896
# ******   away_s_p1   ********
# auc: 0.8048107600000001
# ******   away_s_p2   ********
# auc: 0.8048107600000001
# ******   odds_home_team_win   ********
# auc: 0.80366388
# ******   home_team_match_nr   ********
# auc: 0.8047339600000001
# ******   home_team_opponents_goal_roll3_sum   ********
# auc: 0.8047855599999999
# ******   home_team_opponents_shot_roll2_sum   ********
# auc: 0.80473452
# ******   home_team_shot_on_target_roll4_sum   ********
# auc: 0.80122152
# ******   home_team_opponents_shot_on_target_roll3_sum   ********
# auc: 0.80075208
# ******   home_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.79956832
# ******   home_team_corner_roll3_sum   ********
# auc: 0.8046448799999999
# ******   home_team_corner_roll4_sum   ********
# auc: 0.8037598
# ******   home_team_opponents_corner_roll1_sum   ********
# auc: 0.8043334799999999
# ******   home_team_opponents_corner_roll2_sum   ********
# auc: 0.80405056
# ******   home_team_opponents_corner_roll3_sum   ********
# auc: 0.80376528
# ******   home_team_opponents_corner_roll4_sum   ********
# auc: 0.8033063199999999
# ******   home_team_yellow_card_roll3_sum   ********
# auc: 0.8035892
# ******   home_team_yellow_card_roll4_sum   ********
# auc: 0.80304796
# ******   home_team_opponents_yellow_card_roll1_sum   ********
# auc: 0.8043285200000001
# ******   home_team_opponents_yellow_card_roll2_sum   ********
# auc: 0.8042164
# ******   home_team_opponents_yellow_card_roll3_sum   ********
# auc: 0.8033824400000001
# ******   home_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.80315096
# ******   home_team_opponents_red_card_roll3_sum   ********
# auc: 0.8039853200000001
# ******   odds_home_team_draw_roll2_mean   ********
# auc: 0.79834004
# ******   odds_home_team_defeat_roll2_mean   ********
# auc: 0.7996458
# ******   home_team_point_mean   ********
# auc: 0.80356356
# ******   away_team_match_nr   ********
# auc: 0.80479296
# ******   away_team_goal_roll1_sum   ********
# auc: 0.80474804
# ******   away_team_goal_roll2_sum   ********
# auc: 0.8047252000000001
# ******   away_team_goal_roll3_sum   ********
# auc: 0.8046916399999999
# ******   away_team_goal_roll4_sum   ********
# auc: 0.80467616
# ******   away_team_shot_roll1_sum   ********
# auc: 0.80456832
# ******   away_team_shot_roll2_sum   ********
# auc: 0.8045686800000001
# ******   away_team_shot_roll3_sum   ********
# auc: 0.80430992
# ******   away_team_opponents_shot_roll1_sum   ********
# auc: 0.80477704
# ******   away_team_opponents_shot_roll2_sum   ********
# auc: 0.8047314
# ******   away_team_opponents_shot_roll3_sum   ********
# auc: 0.8045184400000001
# ******   away_team_opponents_shot_roll4_sum   ********
# auc: 0.8045855599999999
# ******   away_team_shot_on_target_roll1_sum   ********
# auc: 0.80488024
# ******   away_team_shot_on_target_roll3_sum   ********
# auc: 0.8039362
# ******   away_team_shot_on_target_roll4_sum   ********
# auc: 0.8026284399999999
# ******   away_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.79652996
# ******   away_team_fault_roll1_sum   ********
# auc: 0.8045273600000001
# ******   away_team_corner_roll1_sum   ********
# auc: 0.8046701599999999
# ******   away_team_corner_roll2_sum   ********
# auc: 0.80417216
# ******   away_team_corner_roll3_sum   ********
# auc: 0.8034714399999999
# ******   away_team_corner_roll4_sum   ********
# auc: 0.80295756
# ******   away_team_opponents_corner_roll1_sum   ********
# auc: 0.8048136400000001
# ******   away_team_opponents_corner_roll2_sum   ********
# auc: 0.80447048
# ******   away_team_opponents_corner_roll3_sum   ********
# auc: 0.80427516
# ******   away_team_opponents_corner_roll4_sum   ********
# auc: 0.8035846400000001
# ******   away_team_yelllow_card_roll2_sum   ********
# auc: 0.80432732
# ******   away_team_yelllow_card_roll3_sum   ********
# auc: 0.8042592000000001
# ******   away_team_yelllow_card_roll4_sum   ********
# auc: 0.8041506399999999
# ******   away_team_opponents_yellow_card_roll3_sum   ********
# auc: 0.80368628
# ******   away_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.80298252
# ******   away_team_red_card_roll4_sum   ********
# auc: 0.80429076
# ******   away_team_opponents_red_card_roll4_sum   ********
# auc: 0.8046027600000001
# ******   away_team_expected_point_roll1_sum   ********
# auc: 0.8047336799999999
# ******   away_team_expected_point_roll2_sum   ********
# auc: 0.80475064
# ******   away_team_expected_point_roll3_sum   ********
# auc: 0.8047804000000001
# ******   away_team_expected_point_roll4_sum   ********
# auc: 0.80473644
# ******   away_team_point_mean   ********
# auc: 0.80405772
# ******   away_team_expected_point_mean   ********
# auc: 0.8032838800000001
# ******   home_team_all_points_diff   ********
# auc: 0.8007322
# ******   away_team_all_points_diff   ********
# auc: 0.8041157999999999
# ******   home_s_p1   ********
# auc: 0.8048466
# ******   home_s_p2   ********
# auc: 0.8048466
# ******   away_s_p1   ********
# auc: 0.8048549999999999
# ******   away_s_p2   ********
# auc: 0.8048549999999999
# ******   odds_home_team_win   ********
# auc: 0.8033787200000001
# ******   home_team_match_nr   ********
# auc: 0.80477524
# ******   home_team_opponents_goal_roll3_sum   ********
# auc: 0.8048074800000001
# ******   home_team_opponents_shot_roll2_sum   ********
# auc: 0.8047823199999999
# ******   home_team_shot_on_target_roll4_sum   ********
# auc: 0.801866
# ******   home_team_opponents_shot_on_target_roll3_sum   ********
# auc: 0.8007163600000001
# ******   home_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.7995068
# ******   home_team_corner_roll3_sum   ********
# auc: 0.8048806799999999
# ******   home_team_corner_roll4_sum   ********
# auc: 0.8040210000000001
# ******   home_team_opponents_corner_roll1_sum   ********
# auc: 0.8043520000000001
# ******   home_team_opponents_corner_roll2_sum   ********
# auc: 0.80404408
# ******   home_team_opponents_corner_roll3_sum   ********
# auc: 0.80376888
# ******   home_team_opponents_corner_roll4_sum   ********
# auc: 0.8032980000000002
# ******   home_team_yellow_card_roll3_sum   ********
# auc: 0.8036654400000001
# ******   home_team_yellow_card_roll4_sum   ********
# auc: 0.80313524
# ******   home_team_opponents_yellow_card_roll1_sum   ********
# auc: 0.8043743999999999
# ******   home_team_opponents_yellow_card_roll2_sum   ********
# auc: 0.8042829199999999
# ******   home_team_opponents_yellow_card_roll3_sum   ********
# auc: 0.8034458000000001
# ******   home_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.80319692
# ******   home_team_opponents_red_card_roll3_sum   ********
# auc: 0.80395316
# ******   odds_home_team_draw_roll2_mean   ********
# auc: 0.79819196
# ******   odds_home_team_defeat_roll2_mean   ********
# auc: 0.7997698000000001
# ******   home_team_point_mean   ********
# auc: 0.80357072
# ******   away_team_match_nr   ********
# auc: 0.8048345600000001
# ******   away_team_goal_roll1_sum   ********
# auc: 0.80534224
# ******   away_team_goal_roll2_sum   ********
# auc: 0.8051093599999999
# ******   away_team_goal_roll3_sum   ********
# auc: 0.80514776
# ******   away_team_goal_roll4_sum   ********
# auc: 0.8049458
# ******   away_team_shot_roll1_sum   ********
# auc: 0.80508112
# ******   away_team_shot_roll2_sum   ********
# auc: 0.8049666799999999
# ******   away_team_shot_roll3_sum   ********
# auc: 0.80477168
# ******   away_team_opponents_shot_roll1_sum   ********
# auc: 0.80476524
# ******   away_team_opponents_shot_roll2_sum   ********
# auc: 0.8047208
# ******   away_team_opponents_shot_roll3_sum   ********
# auc: 0.8044785999999998
# ******   away_team_opponents_shot_roll4_sum   ********
# auc: 0.8045393200000001
# ******   away_team_shot_on_target_roll3_sum   ********
# auc: 0.8002288
# ******   away_team_shot_on_target_roll4_sum   ********
# auc: 0.79908088
# ******   away_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.79700308
# ******   away_team_fault_roll1_sum   ********
# auc: 0.80477224
# ******   away_team_corner_roll1_sum   ********
# auc: 0.8044626800000001
# ******   away_team_corner_roll2_sum   ********
# auc: 0.8040502400000001
# ******   away_team_corner_roll3_sum   ********
# auc: 0.80327804
# ******   away_team_corner_roll4_sum   ********
# auc: 0.80270588
# ******   away_team_opponents_corner_roll1_sum   ********
# auc: 0.80506684
# ******   away_team_opponents_corner_roll2_sum   ********
# auc: 0.8046638399999999
# ******   away_team_opponents_corner_roll3_sum   ********
# auc: 0.80449592
# ******   away_team_opponents_corner_roll4_sum   ********
# auc: 0.80384968
# ******   away_team_yelllow_card_roll2_sum   ********
# auc: 0.80432412
# ******   away_team_yelllow_card_roll3_sum   ********
# auc: 0.8042237199999999
# ******   away_team_yelllow_card_roll4_sum   ********
# auc: 0.8040744799999999
# ******   away_team_opponents_yellow_card_roll3_sum   ********
# auc: 0.8038224
# ******   away_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.8031246000000001
# ******   away_team_red_card_roll4_sum   ********
# auc: 0.8043792799999999
# ******   away_team_opponents_red_card_roll4_sum   ********
# auc: 0.8044471599999999
# ******   away_team_expected_point_roll1_sum   ********
# auc: 0.804564
# ******   away_team_expected_point_roll2_sum   ********
# auc: 0.8047908000000001
# ******   away_team_expected_point_roll3_sum   ********
# auc: 0.80488216
# ******   away_team_expected_point_roll4_sum   ********
# auc: 0.8048744000000001
# ******   away_team_point_mean   ********
# auc: 0.8042469600000001
# ******   away_team_expected_point_mean   ********
# auc: 0.80391156
# ******   home_team_all_points_diff   ********
# auc: 0.8008822
# ******   away_team_all_points_diff   ********
# auc: 0.8046178399999998
# ******   home_s_p1   ********
# auc: 0.8048812000000001
# ******   home_s_p2   ********
# auc: 0.8048812000000001
# ******   away_s_p1   ********
# auc: 0.8048915600000001
# ******   away_s_p2   ********
# auc: 0.8048915600000001
# ******   odds_home_team_win   ********
# auc: 0.80391708
# ******   home_team_match_nr   ********
# auc: 0.80523708
# ******   home_team_opponents_goal_roll3_sum   ********
# auc: 0.80526812
# ******   home_team_opponents_shot_roll2_sum   ********
# auc: 0.80523104
# ******   home_team_shot_on_target_roll4_sum   ********
# auc: 0.8023520000000001
# ******   home_team_opponents_shot_on_target_roll3_sum   ********
# auc: 0.8012039599999999
# ******   home_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.79999544
# ******   home_team_corner_roll3_sum   ********
# auc: 0.8053626
# ******   home_team_corner_roll4_sum   ********
# auc: 0.80450456
# ******   home_team_opponents_corner_roll1_sum   ********
# auc: 0.80482668
# ******   home_team_opponents_corner_roll2_sum   ********
# auc: 0.80451804
# ******   home_team_opponents_corner_roll3_sum   ********
# auc: 0.80424268
# ******   home_team_opponents_corner_roll4_sum   ********
# auc: 0.80376752
# ******   home_team_yellow_card_roll3_sum   ********
# auc: 0.8041354799999999
# ******   home_team_yellow_card_roll4_sum   ********
# auc: 0.8036443199999999
# ******   home_team_opponents_yellow_card_roll1_sum   ********
# auc: 0.80482612
# ******   home_team_opponents_yellow_card_roll2_sum   ********
# auc: 0.80474496
# ******   home_team_opponents_yellow_card_roll3_sum   ********
# auc: 0.8038972400000001
# ******   home_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.8036514
# ******   home_team_opponents_red_card_roll3_sum   ********
# auc: 0.8044338799999999
# ******   odds_home_team_draw_roll2_mean   ********
# auc: 0.7986663199999999
# ******   odds_home_team_defeat_roll2_mean   ********
# auc: 0.80022732
# ******   home_team_point_mean   ********
# auc: 0.80405588
# ******   away_team_match_nr   ********
# auc: 0.80529184
# ******   away_team_goal_roll2_sum   ********
# auc: 0.80537892
# ******   away_team_goal_roll3_sum   ********
# auc: 0.8054197200000002
# ******   away_team_goal_roll4_sum   ********
# auc: 0.8052872399999998
# ******   away_team_shot_roll1_sum   ********
# auc: 0.8054787600000001
# ******   away_team_shot_roll2_sum   ********
# auc: 0.8053982000000001
# ******   away_team_shot_roll3_sum   ********
# auc: 0.8051767600000002
# ******   away_team_opponents_shot_roll1_sum   ********
# auc: 0.8052219999999999
# ******   away_team_opponents_shot_roll2_sum   ********
# auc: 0.8051872400000002
# ******   away_team_opponents_shot_roll3_sum   ********
# auc: 0.8049435200000001
# ******   away_team_opponents_shot_roll4_sum   ********
# auc: 0.8050136800000001
# ******   away_team_shot_on_target_roll3_sum   ********
# auc: 0.8012289199999999
# ******   away_team_shot_on_target_roll4_sum   ********
# auc: 0.8001102
# ******   away_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.79731116
# ******   away_team_fault_roll1_sum   ********
# auc: 0.8052050000000001
# ******   away_team_corner_roll1_sum   ********
# auc: 0.8049259999999999
# ******   away_team_corner_roll2_sum   ********
# auc: 0.8045081599999999
# ******   away_team_corner_roll3_sum   ********
# auc: 0.80375648
# ******   away_team_corner_roll4_sum   ********
# auc: 0.80321216
# ******   away_team_opponents_corner_roll1_sum   ********
# auc: 0.8055131200000001
# ******   away_team_opponents_corner_roll2_sum   ********
# auc: 0.80510876
# ******   away_team_opponents_corner_roll3_sum   ********
# auc: 0.80493832
# ******   away_team_opponents_corner_roll4_sum   ********
# auc: 0.8042848
# ******   away_team_yelllow_card_roll2_sum   ********
# auc: 0.8048152800000001
# ******   away_team_yelllow_card_roll3_sum   ********
# auc: 0.8047261199999999
# ******   away_team_yelllow_card_roll4_sum   ********
# auc: 0.8045773599999999
# ******   away_team_opponents_yellow_card_roll3_sum   ********
# auc: 0.80429092
# ******   away_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.8035962400000001
# ******   away_team_red_card_roll4_sum   ********
# auc: 0.8048485599999999
# ******   away_team_opponents_red_card_roll4_sum   ********
# auc: 0.8049380000000002
# ******   away_team_expected_point_roll1_sum   ********
# auc: 0.80507156
# ******   away_team_expected_point_roll2_sum   ********
# auc: 0.8052631599999999
# ******   away_team_expected_point_roll3_sum   ********
# auc: 0.80529928
# ******   away_team_expected_point_roll4_sum   ********
# auc: 0.8053040800000001
# ******   away_team_point_mean   ********
# auc: 0.8046286800000001
# ******   away_team_expected_point_mean   ********
# auc: 0.80422636
# ******   home_team_all_points_diff   ********
# auc: 0.80134616
# ******   away_team_all_points_diff   ********
# auc: 0.804967
# ******   home_s_p1   ********
# auc: 0.80534808
# ******   home_s_p2   ********
# auc: 0.80534808
# ******   away_s_p1   ********
# auc: 0.80535584
# ******   away_s_p2   ********
# auc: 0.80535584
# ******   odds_home_team_win   ********
# auc: 0.80413188
# ******   home_team_match_nr   ********
# auc: 0.805408
# ******   home_team_opponents_goal_roll3_sum   ********
# auc: 0.80544544
# ******   home_team_opponents_shot_roll2_sum   ********
# auc: 0.8054084399999999
# ******   home_team_shot_on_target_roll4_sum   ********
# auc: 0.8027666400000001
# ******   home_team_opponents_shot_on_target_roll3_sum   ********
# auc: 0.80139732
# ******   home_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.8001881999999999
# ******   home_team_corner_roll3_sum   ********
# auc: 0.8055722799999999
# ******   home_team_corner_roll4_sum   ********
# auc: 0.8047430799999999
# ******   home_team_opponents_corner_roll1_sum   ********
# auc: 0.8050038
# ******   home_team_opponents_corner_roll2_sum   ********
# auc: 0.80468116
# ******   home_team_opponents_corner_roll3_sum   ********
# auc: 0.80440412
# ******   home_team_opponents_corner_roll4_sum   ********
# auc: 0.80390072
# ******   home_team_yellow_card_roll3_sum   ********
# auc: 0.80433292
# ******   home_team_yellow_card_roll4_sum   ********
# auc: 0.80385452
# ******   home_team_opponents_yellow_card_roll1_sum   ********
# auc: 0.8050209200000001
# ******   home_team_opponents_yellow_card_roll2_sum   ********
# auc: 0.80494004
# ******   home_team_opponents_yellow_card_roll3_sum   ********
# auc: 0.80410004
# ******   home_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.80383728
# ******   home_team_opponents_red_card_roll3_sum   ********
# auc: 0.80461532
# ******   odds_home_team_draw_roll2_mean   ********
# auc: 0.7988973599999999
# ******   odds_home_team_defeat_roll2_mean   ********
# auc: 0.80051324
# ******   home_team_point_mean   ********
# auc: 0.80425172
# ******   away_team_match_nr   ********
# auc: 0.8054662799999999
# ******   away_team_goal_roll2_sum   ********
# auc: 0.8055745600000002
# ******   away_team_goal_roll3_sum   ********
# auc: 0.80555764
# ******   away_team_goal_roll4_sum   ********
# auc: 0.80545164
# ******   away_team_shot_roll1_sum   ********
# auc: 0.8055942
# ******   away_team_shot_roll2_sum   ********
# auc: 0.80552932
# ******   away_team_shot_roll3_sum   ********
# auc: 0.8052873199999999
# ******   away_team_opponents_shot_roll1_sum   ********
# auc: 0.8054588
# ******   away_team_opponents_shot_roll2_sum   ********
# auc: 0.80541144
# ******   away_team_opponents_shot_roll3_sum   ********
# auc: 0.8051678
# ******   away_team_opponents_shot_roll4_sum   ********
# auc: 0.80524252
# ******   away_team_shot_on_target_roll3_sum   ********
# auc: 0.80158916
# ******   away_team_shot_on_target_roll4_sum   ********
# auc: 0.80044836
# ******   away_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.7970632800000002
# ******   away_team_fault_roll1_sum   ********
# auc: 0.80541316
# ******   away_team_corner_roll1_sum   ********
# auc: 0.8051659600000001
# ******   away_team_corner_roll2_sum   ********
# auc: 0.80475596
# ******   away_team_corner_roll3_sum   ********
# auc: 0.80401852
# ******   away_team_corner_roll4_sum   ********
# auc: 0.8034727600000001
# ******   away_team_opponents_corner_roll2_sum   ********
# auc: 0.8049507599999999
# ******   away_team_opponents_corner_roll3_sum   ********
# auc: 0.80477732
# ******   away_team_opponents_corner_roll4_sum   ********
# auc: 0.8040652
# ******   away_team_yelllow_card_roll2_sum   ********
# auc: 0.80502188
# ******   away_team_yelllow_card_roll3_sum   ********
# auc: 0.804945
# ******   away_team_yelllow_card_roll4_sum   ********
# auc: 0.8048028399999999
# ******   away_team_opponents_yellow_card_roll3_sum   ********
# auc: 0.80443984
# ******   away_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.80371316
# ******   away_team_red_card_roll4_sum   ********
# auc: 0.8050438799999999
# ******   away_team_opponents_red_card_roll4_sum   ********
# auc: 0.8051737200000001
# ******   away_team_expected_point_roll1_sum   ********
# auc: 0.8052986
# ******   away_team_expected_point_roll2_sum   ********
# auc: 0.80543988
# ******   away_team_expected_point_roll3_sum   ********
# auc: 0.80549
# ******   away_team_expected_point_roll4_sum   ********
# auc: 0.8054722
# ******   away_team_point_mean   ********
# auc: 0.8048006799999999
# ******   away_team_expected_point_mean   ********
# auc: 0.80430992
# ******   home_team_all_points_diff   ********
# auc: 0.8016064799999999
# ******   away_team_all_points_diff   ********
# auc: 0.80511264
# ******   home_s_p1   ********
# auc: 0.80551828
# ******   home_s_p2   ********
# auc: 0.80551828
# ******   away_s_p1   ********
# auc: 0.80552712
# ******   away_s_p2   ********
# auc: 0.80552712
# ******   odds_home_team_win   ********
# auc: 0.8043259199999999
# ******   home_team_match_nr   ********
# auc: 0.8054844400000001
# ******   home_team_opponents_goal_roll3_sum   ********
# auc: 0.8055375600000001
# ******   home_team_opponents_shot_roll2_sum   ********
# auc: 0.80545896
# ******   home_team_shot_on_target_roll4_sum   ********
# auc: 0.80279036
# ******   home_team_opponents_shot_on_target_roll3_sum   ********
# auc: 0.80145548
# ******   home_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.8002469599999998
# ******   home_team_corner_roll3_sum   ********
# auc: 0.8056880800000001
# ******   home_team_corner_roll4_sum   ********
# auc: 0.8048616
# ******   home_team_opponents_corner_roll1_sum   ********
# auc: 0.8051062400000001
# ******   home_team_opponents_corner_roll2_sum   ********
# auc: 0.80478692
# ******   home_team_opponents_corner_roll3_sum   ********
# auc: 0.80448764
# ******   home_team_opponents_corner_roll4_sum   ********
# auc: 0.80398432
# ******   home_team_yellow_card_roll3_sum   ********
# auc: 0.80444564
# ******   home_team_yellow_card_roll4_sum   ********
# auc: 0.80390808
# ******   home_team_opponents_yellow_card_roll1_sum   ********
# auc: 0.80509392
# ******   home_team_opponents_yellow_card_roll2_sum   ********
# auc: 0.8050197600000001
# ******   home_team_opponents_yellow_card_roll3_sum   ********
# auc: 0.80418048
# ******   home_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.8039048799999999
# ******   home_team_opponents_red_card_roll3_sum   ********
# auc: 0.80473052
# ******   odds_home_team_draw_roll2_mean   ********
# auc: 0.79891616
# ******   odds_home_team_defeat_roll2_mean   ********
# auc: 0.8006011999999999
# ******   home_team_point_mean   ********
# auc: 0.80437388
# ******   away_team_match_nr   ********
# auc: 0.80554732
# ******   away_team_goal_roll2_sum   ********
# auc: 0.8056106399999999
# ******   away_team_goal_roll3_sum   ********
# auc: 0.8055952399999999
# ******   away_team_goal_roll4_sum   ********
# auc: 0.80549784
# ******   away_team_shot_roll2_sum   ********
# auc: 0.8054856800000001
# ******   away_team_shot_roll3_sum   ********
# auc: 0.8052142
# ******   away_team_opponents_shot_roll1_sum   ********
# auc: 0.8055448399999999
# ******   away_team_opponents_shot_roll2_sum   ********
# auc: 0.8054962399999999
# ******   away_team_opponents_shot_roll3_sum   ********
# auc: 0.8052536800000001
# ******   away_team_opponents_shot_roll4_sum   ********
# auc: 0.8053199200000001
# ******   away_team_shot_on_target_roll3_sum   ********
# auc: 0.80213344
# ******   away_team_shot_on_target_roll4_sum   ********
# auc: 0.80094976
# ******   away_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.7969576
# ******   away_team_fault_roll1_sum   ********
# auc: 0.80548544
# ******   away_team_corner_roll1_sum   ********
# auc: 0.8053463599999999
# ******   away_team_corner_roll2_sum   ********
# auc: 0.80491024
# ******   away_team_corner_roll3_sum   ********
# auc: 0.80420084
# ******   away_team_corner_roll4_sum   ********
# auc: 0.80363072
# ******   away_team_opponents_corner_roll2_sum   ********
# auc: 0.80501092
# ******   away_team_opponents_corner_roll3_sum   ********
# auc: 0.80480036
# ******   away_team_opponents_corner_roll4_sum   ********
# auc: 0.80409812
# ******   away_team_yelllow_card_roll2_sum   ********
# auc: 0.8050967200000001
# ******   away_team_yelllow_card_roll3_sum   ********
# auc: 0.8050241199999999
# ******   away_team_yelllow_card_roll4_sum   ********
# auc: 0.80490376
# ******   away_team_opponents_yellow_card_roll3_sum   ********
# auc: 0.8044958000000001
# ******   away_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.80375592
# ******   away_team_red_card_roll4_sum   ********
# auc: 0.8051151599999999
# ******   away_team_opponents_red_card_roll4_sum   ********
# auc: 0.80531248
# ******   away_team_expected_point_roll1_sum   ********
# auc: 0.80544408
# ******   away_team_expected_point_roll2_sum   ********
# auc: 0.80551984
# ******   away_team_expected_point_roll3_sum   ********
# auc: 0.8055681600000001
# ******   away_team_expected_point_roll4_sum   ********
# auc: 0.80554448
# ******   away_team_point_mean   ********
# auc: 0.8048524400000001
# ******   away_team_expected_point_mean   ********
# auc: 0.80429456
# ******   home_team_all_points_diff   ********
# auc: 0.80170144
# ******   away_team_all_points_diff   ********
# auc: 0.8051338799999999
# ******   home_s_p1   ********
# auc: 0.8055974399999999
# ******   home_s_p2   ********
# auc: 0.8055974399999999
# ******   away_s_p1   ********
# auc: 0.80559636
# ******   away_s_p2   ********
# auc: 0.80559636
# ******   odds_home_team_win   ********
# auc: 0.8044445600000001
# ******   home_team_match_nr   ********
# auc: 0.8055712
# ******   home_team_opponents_goal_roll3_sum   ********
# auc: 0.8055603200000001
# ******   home_team_opponents_shot_roll2_sum   ********
# auc: 0.80534588
# ******   home_team_shot_on_target_roll4_sum   ********
# auc: 0.8017442
# ******   home_team_opponents_shot_on_target_roll3_sum   ********
# auc: 0.80224508
# ******   home_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.8010393599999999
# ******   home_team_corner_roll4_sum   ********
# auc: 0.80213492
# ******   home_team_opponents_corner_roll1_sum   ********
# auc: 0.8051925600000001
# ******   home_team_opponents_corner_roll2_sum   ********
# auc: 0.8049118399999999
# ******   home_team_opponents_corner_roll3_sum   ********
# auc: 0.80464432
# ******   home_team_opponents_corner_roll4_sum   ********
# auc: 0.8041216399999999
# ******   home_team_yellow_card_roll3_sum   ********
# auc: 0.80443224
# ******   home_team_yellow_card_roll4_sum   ********
# auc: 0.80394532
# ******   home_team_opponents_yellow_card_roll1_sum   ********
# auc: 0.80521552
# ******   home_team_opponents_yellow_card_roll2_sum   ********
# auc: 0.80515808
# ******   home_team_opponents_yellow_card_roll3_sum   ********
# auc: 0.8043357200000001
# ******   home_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.8040505200000001
# ******   home_team_opponents_red_card_roll3_sum   ********
# auc: 0.8046010800000001
# ******   odds_home_team_draw_roll2_mean   ********
# auc: 0.79880144
# ******   odds_home_team_defeat_roll2_mean   ********
# auc: 0.7999615599999998
# ******   home_team_point_mean   ********
# auc: 0.80422576
# ******   away_team_match_nr   ********
# auc: 0.8056363200000001
# ******   away_team_goal_roll2_sum   ********
# auc: 0.8056992000000001
# ******   away_team_goal_roll3_sum   ********
# auc: 0.8057133999999999
# ******   away_team_goal_roll4_sum   ********
# auc: 0.80560804
# ******   away_team_shot_roll2_sum   ********
# auc: 0.80557688
# ******   away_team_shot_roll3_sum   ********
# auc: 0.8053157599999999
# ******   away_team_opponents_shot_roll1_sum   ********
# auc: 0.80562236
# ******   away_team_opponents_shot_roll2_sum   ********
# auc: 0.8055608800000001
# ******   away_team_opponents_shot_roll3_sum   ********
# auc: 0.8053086
# ******   away_team_opponents_shot_roll4_sum   ********
# auc: 0.8053666800000001
# ******   away_team_shot_on_target_roll3_sum   ********
# auc: 0.80235544
# ******   away_team_shot_on_target_roll4_sum   ********
# auc: 0.80122768
# ******   away_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.7973214400000002
# ******   away_team_fault_roll1_sum   ********
# auc: 0.8055864400000001
# ******   away_team_corner_roll1_sum   ********
# auc: 0.80539964
# ******   away_team_corner_roll2_sum   ********
# auc: 0.80497852
# ******   away_team_corner_roll3_sum   ********
# auc: 0.8042456
# ******   away_team_corner_roll4_sum   ********
# auc: 0.80361368
# ******   away_team_opponents_corner_roll2_sum   ********
# auc: 0.8051183199999999
# ******   away_team_opponents_corner_roll3_sum   ********
# auc: 0.80490964
# ******   away_team_opponents_corner_roll4_sum   ********
# auc: 0.8042052000000001
# ******   away_team_yelllow_card_roll2_sum   ********
# auc: 0.80516228
# ******   away_team_yelllow_card_roll3_sum   ********
# auc: 0.80513992
# ******   away_team_yelllow_card_roll4_sum   ********
# auc: 0.8049872399999999
# ******   away_team_opponents_yellow_card_roll3_sum   ********
# auc: 0.8046061600000001
# ******   away_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.80388896
# ******   away_team_red_card_roll4_sum   ********
# auc: 0.80519652
# ******   away_team_opponents_red_card_roll4_sum   ********
# auc: 0.8053876400000001
# ******   away_team_expected_point_roll1_sum   ********
# auc: 0.80547596
# ******   away_team_expected_point_roll2_sum   ********
# auc: 0.8056241199999999
# ******   away_team_expected_point_roll3_sum   ********
# auc: 0.80565784
# ******   away_team_expected_point_roll4_sum   ********
# auc: 0.80564016
# ******   away_team_point_mean   ********
# auc: 0.8049871599999999
# ******   away_team_expected_point_mean   ********
# auc: 0.8045345599999999
# ******   home_team_all_points_diff   ********
# auc: 0.8014044800000001
# ******   away_team_all_points_diff   ********
# auc: 0.80535196
# ******   home_s_p1   ********
# auc: 0.8056898
# ******   home_s_p2   ********
# auc: 0.8056898
# ******   away_s_p1   ********
# auc: 0.80569616
# ******   away_s_p2   ********
# auc: 0.80569616
# ******   odds_home_team_win   ********
# auc: 0.80483632
# ******   home_team_match_nr   ********
# auc: 0.8055774400000001
# ******   home_team_opponents_goal_roll3_sum   ********
# auc: 0.8055842400000001
# ******   home_team_opponents_shot_roll2_sum   ********
# auc: 0.80533912
# ******   home_team_shot_on_target_roll4_sum   ********
# auc: 0.80175156
# ******   home_team_opponents_shot_on_target_roll3_sum   ********
# auc: 0.80227328
# ******   home_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.80108688
# ******   home_team_corner_roll4_sum   ********
# auc: 0.80216116
# ******   home_team_opponents_corner_roll1_sum   ********
# auc: 0.80523436
# ******   home_team_opponents_corner_roll2_sum   ********
# auc: 0.804944
# ******   home_team_opponents_corner_roll3_sum   ********
# auc: 0.8046555599999999
# ******   home_team_opponents_corner_roll4_sum   ********
# auc: 0.8041362800000001
# ******   home_team_yellow_card_roll3_sum   ********
# auc: 0.8044776399999999
# ******   home_team_yellow_card_roll4_sum   ********
# auc: 0.80396704
# ******   home_team_opponents_yellow_card_roll1_sum   ********
# auc: 0.8052281599999999
# ******   home_team_opponents_yellow_card_roll2_sum   ********
# auc: 0.80516332
# ******   home_team_opponents_yellow_card_roll3_sum   ********
# auc: 0.80431288
# ******   home_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.8040316399999999
# ******   home_team_opponents_red_card_roll3_sum   ********
# auc: 0.8046073599999999
# ******   odds_home_team_draw_roll2_mean   ********
# auc: 0.79878472
# ******   odds_home_team_defeat_roll2_mean   ********
# auc: 0.7999943999999999
# ******   home_team_point_mean   ********
# auc: 0.8043236
# ******   away_team_match_nr   ********
# auc: 0.80564872
# ******   away_team_goal_roll2_sum   ********
# auc: 0.80545616
# ******   away_team_goal_roll4_sum   ********
# auc: 0.8053767999999999
# ******   away_team_shot_roll2_sum   ********
# auc: 0.8055216000000001
# ******   away_team_shot_roll3_sum   ********
# auc: 0.80522568
# ******   away_team_opponents_shot_roll1_sum   ********
# auc: 0.80564896
# ******   away_team_opponents_shot_roll2_sum   ********
# auc: 0.805583
# ******   away_team_opponents_shot_roll3_sum   ********
# auc: 0.8053383599999999
# ******   away_team_opponents_shot_roll4_sum   ********
# auc: 0.80540484
# ******   away_team_shot_on_target_roll3_sum   ********
# auc: 0.803321
# ******   away_team_shot_on_target_roll4_sum   ********
# auc: 0.80222652
# ******   away_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.7971069199999998
# ******   away_team_fault_roll1_sum   ********
# auc: 0.8055475999999999
# ******   away_team_corner_roll1_sum   ********
# auc: 0.8054234800000001
# ******   away_team_corner_roll2_sum   ********
# auc: 0.8050006
# ******   away_team_corner_roll3_sum   ********
# auc: 0.8042872
# ******   away_team_corner_roll4_sum   ********
# auc: 0.80368116
# ******   away_team_opponents_corner_roll2_sum   ********
# auc: 0.80509228
# ******   away_team_opponents_corner_roll3_sum   ********
# auc: 0.8048919600000001
# ******   away_team_opponents_corner_roll4_sum   ********
# auc: 0.80419668
# ******   away_team_yelllow_card_roll2_sum   ********
# auc: 0.8051927999999999
# ******   away_team_yelllow_card_roll3_sum   ********
# auc: 0.80521356
# ******   away_team_yelllow_card_roll4_sum   ********
# auc: 0.8050442399999999
# ******   away_team_opponents_yellow_card_roll3_sum   ********
# auc: 0.8046097600000001
# ******   away_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.80387584
# ******   away_team_red_card_roll4_sum   ********
# auc: 0.8051808
# ******   away_team_opponents_red_card_roll4_sum   ********
# auc: 0.80544584
# ******   away_team_expected_point_roll1_sum   ********
# auc: 0.8055178799999999
# ******   away_team_expected_point_roll2_sum   ********
# auc: 0.8056273599999999
# ******   away_team_expected_point_roll3_sum   ********
# auc: 0.80566088
# ******   away_team_expected_point_roll4_sum   ********
# auc: 0.80561804
# ******   away_team_point_mean   ********
# auc: 0.80487144
# ******   away_team_expected_point_mean   ********
# auc: 0.8043068
# ******   home_team_all_points_diff   ********
# auc: 0.80137692
# ******   away_team_all_points_diff   ********
# auc: 0.80522728
# ******   home_s_p1   ********
# auc: 0.8057158
# ******   home_s_p2   ********
# auc: 0.8057158
# ******   away_s_p1   ********
# auc: 0.8057186
# ******   away_s_p2   ********
# auc: 0.8057186
# ******   odds_home_team_win   ********
# auc: 0.8048353599999999
# ******   home_team_match_nr   ********
# auc: 0.80559488
# ******   home_team_opponents_goal_roll3_sum   ********
# auc: 0.8055952799999999
# ******   home_team_opponents_shot_roll2_sum   ********
# auc: 0.80535596
# ******   home_team_shot_on_target_roll4_sum   ********
# auc: 0.80176156
# ******   home_team_opponents_shot_on_target_roll3_sum   ********
# auc: 0.8022872
# ******   home_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.80110944
# ******   home_team_corner_roll4_sum   ********
# auc: 0.8021636400000002
# ******   home_team_opponents_corner_roll1_sum   ********
# auc: 0.80524448
# ...
# ******   away_team_corner_roll3_sum   ********
# auc: 0.78851136
# ******   away_team_corner_roll4_sum   ********
# auc: 0.7877838
# ******   away_team_opponents_corner_roll4_sum   ********
# auc: 0.7875474400000001
# ******   away_team_yelllow_card_roll4_sum   ********
# auc: 0.78790432
# ******   away_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.78687196
# ******   away_team_expected_point_mean   ********
# auc: 0.7867251999999999
# ******   home_team_all_points_diff   ********
# auc: 0.78509704
# ******   home_team_shot_on_target_roll4_sum   ********
# auc: 0.7897391999999999
# ******   home_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.77481608
# ******   home_team_corner_roll4_sum   ********
# auc: 0.78738412
# ******   home_team_opponents_corner_roll3_sum   ********
# auc: 0.7888792
# ******   home_team_opponents_corner_roll4_sum   ********
# auc: 0.78818344
# ******   home_team_yellow_card_roll4_sum   ********
# auc: 0.78693252
# ******   home_team_opponents_yellow_card_roll3_sum   ********
# auc: 0.7882636000000001
# ******   home_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.7880325200000001
# ******   odds_home_team_draw_roll2_mean   ********
# auc: 0.7842574
# ******   odds_home_team_defeat_roll2_mean   ********
# auc: 0.7865362
# ******   home_team_point_mean   ********
# auc: 0.78981892
# ******   away_team_shot_on_target_roll4_sum   ********
# auc: 0.77921984
# ******   away_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.7814274800000001
# ******   away_team_corner_roll3_sum   ********
# auc: 0.7887389999999999
# ******   away_team_corner_roll4_sum   ********
# auc: 0.7879966
# ******   away_team_opponents_corner_roll4_sum   ********
# auc: 0.78763568
# ******   away_team_yelllow_card_roll4_sum   ********
# auc: 0.78816648
# ******   away_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.78717772
# ******   away_team_expected_point_mean   ********
# auc: 0.7867093199999999
# ******   home_team_all_points_diff   ********
# auc: 0.78719488
# ******   home_team_shot_on_target_roll4_sum   ********
# auc: 0.78562584
# ******   home_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.7755522
# ******   home_team_corner_roll4_sum   ********
# auc: 0.7858244799999999
# ******   home_team_opponents_corner_roll3_sum   ********
# auc: 0.7880351999999999
# ******   home_team_opponents_corner_roll4_sum   ********
# auc: 0.78738408
# ******   home_team_yellow_card_roll4_sum   ********
# auc: 0.78580024
# ******   home_team_opponents_yellow_card_roll3_sum   ********
# auc: 0.7875572399999999
# ******   home_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.7873308799999998
# ******   odds_home_team_draw_roll2_mean   ********
# auc: 0.78355756
# ******   odds_home_team_defeat_roll2_mean   ********
# auc: 0.7838700399999999
# ******   away_team_shot_on_target_roll4_sum   ********
# auc: 0.77831388
# ******   away_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.7810101599999999
# ******   away_team_corner_roll3_sum   ********
# auc: 0.7877312
# ******   away_team_corner_roll4_sum   ********
# auc: 0.7869916799999999
# ******   away_team_opponents_corner_roll4_sum   ********
# auc: 0.7867431600000001
# ******   away_team_yelllow_card_roll4_sum   ********
# auc: 0.7874020800000001
# ******   away_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.7864518399999999
# ******   away_team_expected_point_mean   ********
# auc: 0.7858940799999998
# ******   home_team_all_points_diff   ********
# auc: 0.78791908
# ******   home_team_shot_on_target_roll4_sum   ********
# auc: 0.7840416400000001
# ******   home_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.77302524
# ******   home_team_corner_roll4_sum   ********
# auc: 0.7841710799999999
# ******   home_team_opponents_corner_roll4_sum   ********
# auc: 0.7853281999999999
# ******   home_team_yellow_card_roll4_sum   ********
# auc: 0.7838746
# ******   home_team_opponents_yellow_card_roll3_sum   ********
# auc: 0.78566768
# ******   home_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.7854420000000001
# ******   odds_home_team_draw_roll2_mean   ********
# auc: 0.78184076
# ******   odds_home_team_defeat_roll2_mean   ********
# auc: 0.7822766400000001
# ******   away_team_shot_on_target_roll4_sum   ********
# auc: 0.776428
# ******   away_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.77903616
# ******   away_team_corner_roll3_sum   ********
# auc: 0.7858704799999999
# ******   away_team_corner_roll4_sum   ********
# auc: 0.7851305199999999
# ******   away_team_opponents_corner_roll4_sum   ********
# auc: 0.78489456
# ******   away_team_yelllow_card_roll4_sum   ********
# auc: 0.78552188
# ******   away_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.7845388400000001
# ******   away_team_expected_point_mean   ********
# auc: 0.78407904
# ******   home_team_all_points_diff   ********
# auc: 0.78623588
# ******   home_team_shot_on_target_roll4_sum   ********
# auc: 0.7816185600000001
# ******   home_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.77296296
# ******   home_team_corner_roll4_sum   ********
# auc: 0.7811918
# ******   home_team_opponents_corner_roll4_sum   ********
# auc: 0.7836734399999999
# ******   home_team_yellow_card_roll4_sum   ********
# auc: 0.78250524
# ******   home_team_opponents_yellow_card_roll3_sum   ********
# auc: 0.78413844
# ******   home_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.78390264
# ******   odds_home_team_draw_roll2_mean   ********
# auc: 0.7781392
# ******   odds_home_team_defeat_roll2_mean   ********
# auc: 0.77947884
# ******   away_team_shot_on_target_roll4_sum   ********
# auc: 0.7743330400000001
# ******   away_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.7785935199999999
# ******   away_team_corner_roll3_sum   ********
# auc: 0.7839070399999999
# ******   away_team_corner_roll4_sum   ********
# auc: 0.7831194
# ******   away_team_opponents_corner_roll4_sum   ********
# auc: 0.7832421199999999
# ******   away_team_yelllow_card_roll4_sum   ********
# auc: 0.7837978800000001
# ******   away_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.7832162
# ******   away_team_expected_point_mean   ********
# auc: 0.781944
# ******   home_team_shot_on_target_roll4_sum   ********
# auc: 0.78035112
# ******   home_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.7700034799999999
# ******   home_team_corner_roll4_sum   ********
# auc: 0.77916096
# ******   home_team_opponents_corner_roll4_sum   ********
# auc: 0.78143148
# ******   home_team_yellow_card_roll4_sum   ********
# auc: 0.7793245599999999
# ******   home_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.78031404
# ******   odds_home_team_draw_roll2_mean   ********
# auc: 0.77586012
# ******   odds_home_team_defeat_roll2_mean   ********
# auc: 0.7776180799999999
# ******   away_team_shot_on_target_roll4_sum   ********
# auc: 0.77179748
# ******   away_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.7765986
# ******   away_team_corner_roll3_sum   ********
# auc: 0.78169464
# ******   away_team_corner_roll4_sum   ********
# auc: 0.7808788399999999
# ******   away_team_opponents_corner_roll4_sum   ********
# auc: 0.78109564
# ******   away_team_yelllow_card_roll4_sum   ********
# auc: 0.78123812
# ******   away_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.7804922
# ******   away_team_expected_point_mean   ********
# auc: 0.779674
# ******   home_team_shot_on_target_roll4_sum   ********
# auc: 0.77787516
# ******   home_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.76730336
# ******   home_team_corner_roll4_sum   ********
# auc: 0.7765572800000001
# ******   home_team_opponents_corner_roll4_sum   ********
# auc: 0.77890564
# ******   home_team_yellow_card_roll4_sum   ********
# auc: 0.7767724
# ******   home_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.7777702799999999
# ******   odds_home_team_draw_roll2_mean   ********
# auc: 0.7730220000000001
# ******   odds_home_team_defeat_roll2_mean   ********
# auc: 0.7751906799999999
# ******   away_team_shot_on_target_roll4_sum   ********
# auc: 0.7675565200000001
# ******   away_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.7753737599999999
# ******   away_team_corner_roll4_sum   ********
# auc: 0.7769656
# ******   away_team_opponents_corner_roll4_sum   ********
# auc: 0.7789874
# ******   away_team_yelllow_card_roll4_sum   ********
# auc: 0.77861256
# ******   away_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.77806592
# ******   away_team_expected_point_mean   ********
# auc: 0.7778265600000001
# ******   home_team_shot_on_target_roll4_sum   ********
# auc: 0.77561192
# ******   home_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.76441136
# ******   home_team_corner_roll4_sum   ********
# auc: 0.7736833599999999
# ******   home_team_opponents_corner_roll4_sum   ********
# auc: 0.77605628
# ******   home_team_yellow_card_roll4_sum   ********
# auc: 0.77374056
# ******   home_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.77492348
# ******   odds_home_team_draw_roll2_mean   ********
# auc: 0.7701776
# ******   odds_home_team_defeat_roll2_mean   ********
# auc: 0.7726728
# ******   away_team_shot_on_target_roll4_sum   ********
# auc: 0.76585808
# ******   away_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.76933012
# ******   away_team_corner_roll4_sum   ********
# auc: 0.774563
# ******   away_team_yelllow_card_roll4_sum   ********
# auc: 0.7756686
# ******   away_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.7749502
# ******   away_team_expected_point_mean   ********
# auc: 0.77432588
# ******   home_team_shot_on_target_roll4_sum   ********
# auc: 0.77308728
# ******   home_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.76023544
# ******   home_team_corner_roll4_sum   ********
# auc: 0.77104096
# ******   home_team_yellow_card_roll4_sum   ********
# auc: 0.7705758000000001
# ******   home_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.7718354799999999
# ******   odds_home_team_draw_roll2_mean   ********
# auc: 0.7672848800000001
# ******   odds_home_team_defeat_roll2_mean   ********
# auc: 0.77014448
# ******   away_team_shot_on_target_roll4_sum   ********
# auc: 0.7627654399999999
# ******   away_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.7659884400000001
# ******   away_team_corner_roll4_sum   ********
# auc: 0.77159068
# ******   away_team_yelllow_card_roll4_sum   ********
# auc: 0.7725443200000001
# ******   away_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.77186552
# ******   away_team_expected_point_mean   ********
# auc: 0.7713747600000002
# ******   home_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.756658
# ******   home_team_corner_roll4_sum   ********
# auc: 0.76195912
# ******   home_team_yellow_card_roll4_sum   ********
# auc: 0.7663830399999999
# ******   home_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.76905264
# ******   odds_home_team_draw_roll2_mean   ********
# auc: 0.7646649999999999
# ******   odds_home_team_defeat_roll2_mean   ********
# auc: 0.76124476
# ******   away_team_shot_on_target_roll4_sum   ********
# auc: 0.75765104
# ******   away_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.76305332
# ******   away_team_corner_roll4_sum   ********
# auc: 0.76790512
# ******   away_team_yelllow_card_roll4_sum   ********
# auc: 0.7692666399999999
# ******   away_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.76859816
# ******   away_team_expected_point_mean   ********
# auc: 0.7681386800000001
# ******   home_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.7516482000000001
# ******   home_team_corner_roll4_sum   ********
# auc: 0.75715232
# ******   home_team_yellow_card_roll4_sum   ********
# auc: 0.7609435600000001
# ******   home_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.7643090800000001
# ******   odds_home_team_draw_roll2_mean   ********
# auc: 0.7596889600000001
# ******   odds_home_team_defeat_roll2_mean   ********
# auc: 0.75714268
# ******   away_team_shot_on_target_roll4_sum   ********
# auc: 0.75149064
# ******   away_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.75981536
# ******   away_team_corner_roll4_sum   ********
# auc: 0.76352796
# ******   away_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.7625236799999999
# ******   away_team_expected_point_mean   ********
# auc: 0.7646137599999999
# ******   home_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.7461091599999999
# ******   home_team_corner_roll4_sum   ********
# auc: 0.75283392
# ******   home_team_yellow_card_roll4_sum   ********
# auc: 0.7561794
# ******   home_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.75944484
# ******   odds_home_team_draw_roll2_mean   ********
# auc: 0.75472184
# ******   odds_home_team_defeat_roll2_mean   ********
# auc: 0.75343732
# ******   away_team_shot_on_target_roll4_sum   ********
# auc: 0.7537568800000001
# ******   away_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.7487228
# ******   away_team_corner_roll4_sum   ********
# auc: 0.7600382000000001
# ******   away_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.75712644
# ******   home_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.7410439600000001
# ******   home_team_corner_roll4_sum   ********
# auc: 0.74763476
# ******   home_team_yellow_card_roll4_sum   ********
# auc: 0.75096164
# ******   home_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.7545561200000002
# ******   odds_home_team_draw_roll2_mean   ********
# auc: 0.74928908
# ******   odds_home_team_defeat_roll2_mean   ********
# auc: 0.74878496
# ******   away_team_shot_on_target_roll4_sum   ********
# auc: 0.7447986
# ******   away_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.7465872
# ******   away_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.75235516
# ******   home_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.73325712
# ******   home_team_corner_roll4_sum   ********
# auc: 0.7415888399999999
# ******   home_team_yellow_card_roll4_sum   ********
# auc: 0.74278712
# ******   odds_home_team_draw_roll2_mean   ********
# auc: 0.74321708
# ******   odds_home_team_defeat_roll2_mean   ********
# auc: 0.74350144
# ******   away_team_shot_on_target_roll4_sum   ********
# auc: 0.73802988
# ******   away_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.74019016
# ******   away_team_opponents_yellow_card_roll4_sum   ********
# auc: 0.7452871600000001
# ******   home_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.72152208
# ******   home_team_corner_roll4_sum   ********
# auc: 0.73059676
# ******   home_team_yellow_card_roll4_sum   ********
# auc: 0.729774
# ******   odds_home_team_draw_roll2_mean   ********
# auc: 0.73293136
# ******   odds_home_team_defeat_roll2_mean   ********
# auc: 0.7343732
# ******   away_team_shot_on_target_roll4_sum   ********
# auc: 0.7278419599999999
# ******   away_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.72643152
# ******   home_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.71315584
# ******   home_team_corner_roll4_sum   ********
# auc: 0.7182464799999999
# ******   home_team_yellow_card_roll4_sum   ********
# auc: 0.7191186
# ******   odds_home_team_draw_roll2_mean   ********
# auc: 0.74111346
# ******   away_team_shot_on_target_roll4_sum   ********
# auc: 0.7152281399999999
# ******   away_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.71640068
# ******   home_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.7227089600000001
# ******   home_team_corner_roll4_sum   ********
# auc: 0.72202902
# ******   home_team_yellow_card_roll4_sum   ********
# auc: 0.7246824000000001
# ******   away_team_shot_on_target_roll4_sum   ********
# auc: 0.7208788799999999
# ******   away_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.7222775
# ******   home_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.7042323799999999
# ******   home_team_corner_roll4_sum   ********
# auc: 0.70166586
# ******   away_team_shot_on_target_roll4_sum   ********
# auc: 0.7003227200000001
# ******   away_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.7011422599999999
# ******   home_team_corner_roll4_sum   ********
# auc: 0.68006546
# ******   away_team_shot_on_target_roll4_sum   ********
# auc: 0.66530762
# ******   away_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.67030242
# ******   away_team_shot_on_target_roll4_sum   ********
# auc: 0.63206866
# ******   away_team_opponents_shot_on_target_roll4_sum   ********
# auc: 0.6364675000000001

# %% [markdown]
# # Final Model ( best AUC score)

# %%
### Train

data = df.copy()

data_y1= data[data['draw_flag']==1].reset_index(drop=True)
data_y0= data[data['draw_flag']==0].reset_index(drop=True)


train_feature = best_features["best_auc"]

train_target = 'draw_flag'

### Train
data_to_train = pd.concat([data_y1[0:11000],data_y0[0:11000]], ignore_index=True)
X_train = data_to_train[train_feature].values
y_train = data_to_train[train_target].values

### Test
data_to_test = pd.concat([data_y1[11000:16000],data_y0[11000:16000]], ignore_index=True)
X_test = data_to_test[train_feature].values
y_test = data_to_test[train_target].values

# %%
model = support_functions.try_models(GaussianNB(),X_train,y_train,X_test,y_test)
# Out:
# ====================
# GaussianNB()
# accuracy of train set: 0.537409090909091
# accuracy of val set: 0.5193
# model mean squared error: 0.4807
# model root mean squared error: 0.6933253204665181
# model R2: -0.9228000000000001

# %%
with open('draw_model.pickle', 'wb') as f:
    pickle.dump(model, f)

# %%
y_prediction = model.predict_proba(X_test)[:,1]
data_to_test["pred"] = y_prediction
auc = roc_auc_score(data_to_test['draw_flag'],data_to_test['pred'] )
print("auc:",auc)
# Out:
# auc: 0.52814056

# %%
mat = confusion_matrix(data_to_test["draw_flag"],
                       (data_to_test["pred"] > 0.5).astype(int))
labels = ['0', '1']
 
sns.heatmap(mat, square=True, annot=True, fmt='d', cbar=False, cmap='Blues',
            xticklabels=labels, yticklabels=labels)

plt.xlabel('Pred')
plt.ylabel('Actual')
# Out:
# Text(91.68, 0.5, 'Actual')
