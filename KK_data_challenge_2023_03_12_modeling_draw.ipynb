# %%
import pandas as pd
import numpy as np

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn import preprocessing as pre
import sklearn

from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt


pd.set_option('display.max_rows', 100)

# %% [markdown]
# # Parameters

# %%
file_path_desc = "D:/Data_challenge/columns_description.xlsx"
file_path_data = "D:/Data_challenge/match_data.csv"

# %% [markdown]
# # Data input

# %%
data = pd.read_csv(file_path_data)
data = data[data['odds_home_team_win']!=0].reset_index(drop = True)
data
# Out:
#        match_id     season    div  odds_home_team_win  odds_draw  \
# 0             0  2008-2009   div0                1.73       3.50
# 1             1  2008-2009   div0                1.25       5.50
# 2             2  2008-2009   div0                1.57       3.80
# 3             3  2008-2009   div0                1.17       7.00
# 4             4  2008-2009   div0                1.17       7.00
# ...         ...        ...    ...                 ...        ...
# 64154     64395  2021-2022  div18                3.80       3.71
# 64155     64396  2021-2022  div18                3.62       3.42
# 64156     64397  2021-2022  div18                5.51       4.06
# 64157     64398  2021-2022  div18                3.83       3.76
# 64158     64399  2021-2022  div18               11.22       6.78
#
#        odds_away_team_win  home_team_match_nr  home_team_goal_roll1_sum  \
# 0                    5.00                   5                         3
# 1                   12.00                   7                         0
# 2                    5.75                   9                         1
# 3                   15.00                  11                         2
# 4                   15.00                  14                         2
# ...                   ...                 ...                       ...
# 64154                1.90                  30                         0
# 64155                2.04                  32                         0
# 64156                1.59                  34                         0
# 64157                1.87                  36                         1
# 64158                1.22                  38                         0
#
#        home_team_goal_roll2_sum  home_team_goal_roll3_sum  ...  \
# 0                             7                         8  ...
# 1                             2                         5  ...
# 2                             4                         4  ...
# 3                             6                         7  ...
# 4                             4                         7  ...
# ...                         ...                       ...  ...
# 64154                         1                         3  ...
# 64155                         0                         0  ...
# 64156                         0                         0  ...
# 64157                         3                         3  ...
# 64158                         1                         2  ...
#
#        odds_away_team_draw_roll4_mean  odds_away_team_defeat_roll1_mean  \
# 0                               3.825                             11.00
# 1                               3.582                              2.10
# 2                               3.525                              6.75
# 3                               3.975                              4.20
# 4                               3.925                              3.10
# ...                               ...                               ...
# 64154                           3.558                              5.04
# 64155                           3.268                              3.03
# 64156                           3.625                              4.19
# 64157                           3.738                              2.04
# 64158                           4.375                              6.16
#
#        odds_away_team_defeat_roll2_mean  odds_away_team_defeat_roll3_mean  \
# 0                                 7.665                             6.377
# 1                                 2.250                             2.833
# 2                                 4.275                             3.883
# 3                                 2.750                             2.333
# 4                                 2.175                             2.050
# ...                                 ...                               ...
# 64154                             3.695                             3.337
# 64155                             2.585                             2.740
# 64156                             3.860                             3.943
# 64157                             1.800                             1.883
# 64158                             4.340                             5.393
#
#        odds_away_team_defeat_roll4_mean  away_team_point_mean  \
# 0                                 5.908                 0.500
# 1                                 2.475                 0.333
# 2                                 3.638                 0.750
# 3                                 2.550                 0.600
# 4                                 2.015                 0.833
# ...                                 ...                   ...
# 64154                             3.043                 0.929
# 64155                             2.755                 1.000
# 64156                             3.458                 1.312
# 64157                             1.915                 0.412
# 64158                             5.432                 1.778
#
#        away_team_expected_point_mean  home_win_flag  draw_flag  away_win_flag
# 0                              3.000              0          0              1
# 1                              0.000              0          1              0
# 2                              1.500              1          0              0
# 3                              0.000              1          0              0
# 4                              0.000              1          0              0
# ...                              ...            ...        ...            ...
# 64154                          0.429              0          0              1
# 64155                          0.200              0          0              1
# 64156                          0.750              0          0              1
# 64157                          0.000              0          0              1
# 64158                          2.333              0          0              1
#
# [64159 rows x 167 columns]

# %% [markdown]
# # EDA

# %%
data.shape
# Out:
# (64159, 167)

# %%
data.columns
# Out:
# Index(['match_id', 'season', 'div', 'odds_home_team_win', 'odds_draw',
#        'odds_away_team_win', 'home_team_match_nr', 'home_team_goal_roll1_sum',
#        'home_team_goal_roll2_sum', 'home_team_goal_roll3_sum',
#        ...
#        'odds_away_team_draw_roll4_mean', 'odds_away_team_defeat_roll1_mean',
#        'odds_away_team_defeat_roll2_mean', 'odds_away_team_defeat_roll3_mean',
#        'odds_away_team_defeat_roll4_mean', 'away_team_point_mean',
#        'away_team_expected_point_mean', 'home_win_flag', 'draw_flag',
#        'away_win_flag'],
#       dtype='object', length=167)

# %%
print("Home win count: " + str(sum(data.home_win_flag)))
print("Draw count: " + str(sum(data.draw_flag)))
print("Away win count: " + str(sum(data.away_win_flag)))
# Out:
# Home win count: 28211
# Draw count: 16796
# Away win count: 19152

# %% [markdown]
# # Data preparation

# %%
data['home_win_prob'] = 1/data['odds_home_team_win']
data['draw_prob'] = 1/data['odds_draw']
data['away_win_prob'] = 1/data['odds_away_team_win']
data['delta_prob'] = data['home_win_prob'] - data['away_win_prob'] 

#data = data[data['draw_prob']<0.37].reset_index()
data
# Out:
#        match_id     season    div  odds_home_team_win  odds_draw  \
# 0             0  2008-2009   div0                1.73       3.50
# 1             1  2008-2009   div0                1.25       5.50
# 2             2  2008-2009   div0                1.57       3.80
# 3             3  2008-2009   div0                1.17       7.00
# 4             4  2008-2009   div0                1.17       7.00
# ...         ...        ...    ...                 ...        ...
# 64154     64395  2021-2022  div18                3.80       3.71
# 64155     64396  2021-2022  div18                3.62       3.42
# 64156     64397  2021-2022  div18                5.51       4.06
# 64157     64398  2021-2022  div18                3.83       3.76
# 64158     64399  2021-2022  div18               11.22       6.78
#
#        odds_away_team_win  home_team_match_nr  home_team_goal_roll1_sum  \
# 0                    5.00                   5                         3
# 1                   12.00                   7                         0
# 2                    5.75                   9                         1
# 3                   15.00                  11                         2
# 4                   15.00                  14                         2
# ...                   ...                 ...                       ...
# 64154                1.90                  30                         0
# 64155                2.04                  32                         0
# 64156                1.59                  34                         0
# 64157                1.87                  36                         1
# 64158                1.22                  38                         0
#
#        home_team_goal_roll2_sum  home_team_goal_roll3_sum  ...  \
# 0                             7                         8  ...
# 1                             2                         5  ...
# 2                             4                         4  ...
# 3                             6                         7  ...
# 4                             4                         7  ...
# ...                         ...                       ...  ...
# 64154                         1                         3  ...
# 64155                         0                         0  ...
# 64156                         0                         0  ...
# 64157                         3                         3  ...
# 64158                         1                         2  ...
#
#        odds_away_team_defeat_roll4_mean  away_team_point_mean  \
# 0                                 5.908                 0.500
# 1                                 2.475                 0.333
# 2                                 3.638                 0.750
# 3                                 2.550                 0.600
# 4                                 2.015                 0.833
# ...                                 ...                   ...
# 64154                             3.043                 0.929
# 64155                             2.755                 1.000
# 64156                             3.458                 1.312
# 64157                             1.915                 0.412
# 64158                             5.432                 1.778
#
#        away_team_expected_point_mean  home_win_flag  draw_flag  away_win_flag  \
# 0                              3.000              0          0              1
# 1                              0.000              0          1              0
# 2                              1.500              1          0              0
# 3                              0.000              1          0              0
# 4                              0.000              1          0              0
# ...                              ...            ...        ...            ...
# 64154                          0.429              0          0              1
# 64155                          0.200              0          0              1
# 64156                          0.750              0          0              1
# 64157                          0.000              0          0              1
# 64158                          2.333              0          0              1
#
#        home_win_prob  draw_prob  away_win_prob  delta_prob
# 0           0.578035   0.285714       0.200000    0.378035
# 1           0.800000   0.181818       0.083333    0.716667
# 2           0.636943   0.263158       0.173913    0.463030
# 3           0.854701   0.142857       0.066667    0.788034
# 4           0.854701   0.142857       0.066667    0.788034
# ...              ...        ...            ...         ...
# 64154       0.263158   0.269542       0.526316   -0.263158
# 64155       0.276243   0.292398       0.490196   -0.213953
# 64156       0.181488   0.246305       0.628931   -0.447443
# 64157       0.261097   0.265957       0.534759   -0.273663
# 64158       0.089127   0.147493       0.819672   -0.730546
#
# [64159 rows x 171 columns]

# %%
pd.DataFrame(data.columns)
# Out:
#                       0
# 0              match_id
# 1                season
# 2                   div
# 3    odds_home_team_win
# 4             odds_draw
# ..                  ...
# 166       away_win_flag
# 167       home_win_prob
# 168           draw_prob
# 169       away_win_prob
# 170          delta_prob
#
# [171 rows x 1 columns]

# %% [markdown]
# # Draw modeling

# %% [markdown]
# # Train, test split

# %%
dataset = data.copy()
dataset = dataset.drop(['home_win_flag'], axis=1)
dataset = dataset.drop(['away_win_flag'], axis=1)
dataset = dataset.drop(['match_id'], axis=1)
dataset = dataset.drop(['season'], axis=1)
dataset = dataset.drop(['div'], axis=1)
dataset = dataset.drop(['odds_away_team_win'], axis=1)
dataset = dataset.drop(['odds_draw'], axis=1)
dataset = dataset.drop(['odds_home_team_win'], axis=1)
y = dataset['draw_flag']
X = dataset.drop(['draw_flag'], axis=1) 
X
# Out:
#        home_team_match_nr  home_team_goal_roll1_sum  home_team_goal_roll2_sum  \
# 0                       5                         3                         7
# 1                       7                         0                         2
# 2                       9                         1                         4
# 3                      11                         2                         6
# 4                      14                         2                         4
# ...                   ...                       ...                       ...
# 64154                  30                         0                         1
# 64155                  32                         0                         0
# 64156                  34                         0                         0
# 64157                  36                         1                         3
# 64158                  38                         0                         1
#
#        home_team_goal_roll3_sum  home_team_goal_roll4_sum  \
# 0                             8                        10
# 1                             5                         9
# 2                             4                         6
# 3                             7                        10
# 4                             7                         9
# ...                         ...                       ...
# 64154                         3                         3
# 64155                         0                         1
# 64156                         0                         0
# 64157                         3                         3
# 64158                         2                         4
#
#        home_team_opponents_goal_roll1_sum  home_team_opponents_goal_roll2_sum  \
# 0                                       0                                   1
# 1                                       1                                   6
# 2                                       0                                   3
# 3                                       1                                   3
# 4                                       2                                   3
# ...                                   ...                                 ...
# 64154                                   1                                   1
# 64155                                   1                                   3
# 64156                                   2                                   3
# 64157                                   2                                   5
# 64158                                   3                                   6
#
#        home_team_opponents_goal_roll3_sum  home_team_opponents_goal_roll4_sum  \
# 0                                       2                                   4
# 1                                       6                                   7
# 2                                       4                                   9
# 3                                       3                                   6
# 4                                       4                                   5
# ...                                   ...                                 ...
# 64154                                   6                                   6
# 64155                                   4                                   4
# 64156                                   4                                   6
# 64157                                   7                                   8
# 64158                                   8                                  11
#
#        home_team_shot_roll1_sum  ...  odds_away_team_defeat_roll1_mean  \
# 0                            11  ...                             11.00
# 1                            13  ...                              2.10
# 2                            16  ...                              6.75
# 3                            15  ...                              4.20
# 4                            11  ...                              3.10
# ...                         ...  ...                               ...
# 64154                         6  ...                              5.04
# 64155                         7  ...                              3.03
# 64156                        15  ...                              4.19
# 64157                         4  ...                              2.04
# 64158                        12  ...                              6.16
#
#        odds_away_team_defeat_roll2_mean  odds_away_team_defeat_roll3_mean  \
# 0                                 7.665                             6.377
# 1                                 2.250                             2.833
# 2                                 4.275                             3.883
# 3                                 2.750                             2.333
# 4                                 2.175                             2.050
# ...                                 ...                               ...
# 64154                             3.695                             3.337
# 64155                             2.585                             2.740
# 64156                             3.860                             3.943
# 64157                             1.800                             1.883
# 64158                             4.340                             5.393
#
#        odds_away_team_defeat_roll4_mean  away_team_point_mean  \
# 0                                 5.908                 0.500
# 1                                 2.475                 0.333
# 2                                 3.638                 0.750
# 3                                 2.550                 0.600
# 4                                 2.015                 0.833
# ...                                 ...                   ...
# 64154                             3.043                 0.929
# 64155                             2.755                 1.000
# 64156                             3.458                 1.312
# 64157                             1.915                 0.412
# 64158                             5.432                 1.778
#
#        away_team_expected_point_mean  home_win_prob  draw_prob  away_win_prob  \
# 0                              3.000       0.578035   0.285714       0.200000
# 1                              0.000       0.800000   0.181818       0.083333
# 2                              1.500       0.636943   0.263158       0.173913
# 3                              0.000       0.854701   0.142857       0.066667
# 4                              0.000       0.854701   0.142857       0.066667
# ...                              ...            ...        ...            ...
# 64154                          0.429       0.263158   0.269542       0.526316
# 64155                          0.200       0.276243   0.292398       0.490196
# 64156                          0.750       0.181488   0.246305       0.628931
# 64157                          0.000       0.261097   0.265957       0.534759
# 64158                          2.333       0.089127   0.147493       0.819672
#
#        delta_prob
# 0        0.378035
# 1        0.716667
# 2        0.463030
# 3        0.788034
# 4        0.788034
# ...           ...
# 64154   -0.263158
# 64155   -0.213953
# 64156   -0.447443
# 64157   -0.273663
# 64158   -0.730546
#
# [64159 rows x 162 columns]

# %%
#scaled X
x_tra = X.values #returns a numpy array
min_max_scaler = pre.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x_tra)
X = pd.DataFrame(x_scaled)

# train test


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.10, random_state=1)
X_train.shape[1]
# Out:
# 162

# %% [markdown]
# ### Previous version

# %%
### Train 
# dataset = data.copy()
# data_y1= dataset[dataset['home_win_flag']==1].reset_index(drop=True)
# data_y0= dataset[dataset['home_win_flag']==0].reset_index(drop=True)

# data_to_train = pd.concat([data_y1[0:20000],data_y0[0:20000]], ignore_index=True)

# y_train = data_to_train.iloc[:, 164].values

# X_train = data_to_train.drop(['home_win_flag'], axis=1)
# X_train = X_train.drop(['draw_flag'], axis=1)
# X_train = X_train.drop(['away_win_flag'], axis=1)

# X_train = X_train.drop(['odds_home_team_win'], axis=1)
# X_train = X_train.drop(['odds_draw'], axis=1)
# X_train = X_train.drop(['odds_away_team_win'], axis=1)


# print(X_train.columns)
# X_train = X_train.iloc[:, 3:len(X_train)].values

# ### Test

# data_to_test = pd.concat([data_y1[20000:28000],data_y0[20000:28000]], ignore_index=True)

# y_test = data_to_test.iloc[:, 164].values

# X_test = data_to_test.drop(['home_win_flag'], axis=1)
# X_test = X_test.drop(['draw_flag'], axis=1)
# X_test = X_test.drop(['away_win_flag'], axis=1)

# X_test = X_test.drop(['odds_home_team_win'], axis=1)
# X_test = X_test.drop(['odds_draw'], axis=1)
# X_test = X_test.drop(['odds_away_team_win'], axis=1)


# X_test = X_test.iloc[:, 3:len(X_test)].values

# %% [markdown]
# # Modeling WIP

# %% [markdown]
# ## Keras

# %%
model = Sequential()
model.add(Dense(500, activation='relu', input_dim=X_train.shape[1]))
model.add(Dense(100, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', 
              loss='binary_crossentropy', 
              metrics=['accuracy','AUC'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 500)               81500
#
#  dense_5 (Dense)             (None, 100)               50100
#
#  dense_6 (Dense)             (None, 50)                5050
#
#  dense_7 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 136,701
# Trainable params: 136,701
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=41)#41,74
# Out:
# Epoch 1/41
# 1805/1805 [==============================] - 4s 2ms/step - loss: 0.5754 - accuracy: 0.7379 - auc: 0.5263 - val_loss: 0.5736 - val_accuracy: 0.7392 - val_auc: 0.5422
# Epoch 2/41
# 1805/1805 [==============================] - 3s 2ms/step - loss: 0.5724 - accuracy: 0.7381 - auc: 0.5445 - val_loss: 0.5687 - val_accuracy: 0.7392 - val_auc: 0.5552
# Epoch 3/41
# 1805/1805 [==============================] - 3s 2ms/step - loss: 0.5710 - accuracy: 0.7381 - auc: 0.5526 - val_loss: 0.5693 - val_accuracy: 0.7392 - val_auc: 0.5565
# Epoch 4/41
# 1805/1805 [==============================] - 3s 2ms/step - loss: 0.5707 - accuracy: 0.7381 - auc: 0.5518 - val_loss: 0.5684 - val_accuracy: 0.7392 - val_auc: 0.5558
# Epoch 5/41
# 1805/1805 [==============================] - 3s 2ms/step - loss: 0.5700 - accuracy: 0.7381 - auc: 0.5549 - val_loss: 0.5692 - val_accuracy: 0.7392 - val_auc: 0.5571
# Epoch 6/41
# 1805/1805 [==============================] - 3s 2ms/step - loss: 0.5698 - accuracy: 0.7381 - auc: 0.5574 - val_loss: 0.5686 - val_accuracy: 0.7392 - val_auc: 0.5545
# Epoch 7/41
# 1805/1805 [==============================] - 3s 2ms/step - loss: 0.5696 - accuracy: 0.7381 - auc: 0.5584 - val_loss: 0.5686 - val_accuracy: 0.7392 - val_auc: 0.5525
# Epoch 8/41
# 1805/1805 [==============================] - 3s 2ms/step - loss: 0.5690 - accuracy: 0.7381 - auc: 0.5623 - val_loss: 0.5689 - val_accuracy: 0.7392 - val_auc: 0.5534
# Epoch 9/41
# 1805/1805 [==============================] - 3s 2ms/step - loss: 0.5691 - accuracy: 0.7381 - auc: 0.5616 - val_loss: 0.5697 - val_accuracy: 0.7392 - val_auc: 0.5528
# Epoch 10/41
# 1805/1805 [==============================] - 3s 2ms/step - loss: 0.5687 - accuracy: 0.7381 - auc: 0.5647 - val_loss: 0.5690 - val_accuracy: 0.7392 - val_auc: 0.5549
# Epoch 11/41
# 1805/1805 [==============================] - 3s 2ms/step - loss: 0.5685 - accuracy: 0.7381 - auc: 0.5641 - val_loss: 0.5693 - val_accuracy: 0.7392 - val_auc: 0.5537
# Epoch 12/41
# 1805/1805 [==============================] - 3s 2ms/step - loss: 0.5684 - accuracy: 0.7381 - auc: 0.5654 - val_loss: 0.5714 - val_accuracy: 0.7392 - val_auc: 0.5524
# Epoch 13/41
# 1805/1805 [==============================] - 3s 2ms/step - loss: 0.5683 - accuracy: 0.7381 - auc: 0.5652 - val_loss: 0.5695 - val_accuracy: 0.7392 - val_auc: 0.5528
# Epoch 14/41
# 1805/1805 [==============================] - 3s 2ms/step - loss: 0.5679 - accuracy: 0.7381 - auc: 0.5695 - val_loss: 0.5695 - val_accuracy: 0.7392 - val_auc: 0.5560
# Epoch 15/41
# 1805/1805 [==============================] - 3s 2ms/step - loss: 0.5681 - accuracy: 0.7381 - auc: 0.5664 - val_loss: 0.5697 - val_accuracy: 0.7392 - val_auc: 0.5526
# Epoch 16/41
# 1805/1805 [==============================] - 3s 2ms/step - loss: 0.5680 - accuracy: 0.7381 - auc: 0.5676 - val_loss: 0.5694 - val_accuracy: 0.7392 - val_auc: 0.5568
# Epoch 17/41
# 1805/1805 [==============================] - 3s 2ms/step - loss: 0.5676 - accuracy: 0.7381 - auc: 0.5695 - val_loss: 0.5690 - val_accuracy: 0.7392 - val_auc: 0.5580
# Epoch 18/41
# 1805/1805 [==============================] - 3s 2ms/step - loss: 0.5674 - accuracy: 0.7381 - auc: 0.5714 - val_loss: 0.5723 - val_accuracy: 0.7392 - val_auc: 0.5534
# Epoch 19/41
# 1805/1805 [==============================] - 3s 2ms/step - loss: 0.5673 - accuracy: 0.7381 - auc: 0.5727 - val_loss: 0.5703 - val_accuracy: 0.7392 - val_auc: 0.5560
# Epoch 20/41
# 1805/1805 [==============================] - 3s 2ms/step - loss: 0.5669 - accuracy: 0.7381 - auc: 0.5740 - val_loss: 0.5695 - val_accuracy: 0.7392 - val_auc: 0.5541
# Epoch 21/41
# 1805/1805 [==============================] - 3s 2ms/step - loss: 0.5665 - accuracy: 0.7381 - auc: 0.5773 - val_loss: 0.5699 - val_accuracy: 0.7392 - val_auc: 0.5543
# Epoch 22/41
# 1805/1805 [==============================] - 3s 2ms/step - loss: 0.5665 - accuracy: 0.7381 - auc: 0.5764 - val_loss: 0.5717 - val_accuracy: 0.7392 - val_auc: 0.5533
# Epoch 23/41
# 1805/1805 [==============================] - 3s 2ms/step - loss: 0.5664 - accuracy: 0.7381 - auc: 0.5784 - val_loss: 0.5745 - val_accuracy: 0.7392 - val_auc: 0.5559
# Epoch 24/41
# 1805/1805 [==============================] - 3s 2ms/step - loss: 0.5662 - accuracy: 0.7381 - auc: 0.5783 - val_loss: 0.5715 - val_accuracy: 0.7392 - val_auc: 0.5555
# Epoch 25/41
# 1805/1805 [==============================] - 3s 2ms/step - loss: 0.5658 - accuracy: 0.7381 - auc: 0.5804 - val_loss: 0.5729 - val_accuracy: 0.7392 - val_auc: 0.5515
# Epoch 26/41
# 1805/1805 [==============================] - 3s 2ms/step - loss: 0.5658 - accuracy: 0.7381 - auc: 0.5788 - val_loss: 0.5701 - val_accuracy: 0.7392 - val_auc: 0.5553
# Epoch 27/41
# 1805/1805 [==============================] - 3s 2ms/step - loss: 0.5652 - accuracy: 0.7381 - auc: 0.5823 - val_loss: 0.5703 - val_accuracy: 0.7392 - val_auc: 0.5534
# Epoch 28/41
# 1805/1805 [==============================] - 3s 2ms/step - loss: 0.5650 - accuracy: 0.7381 - auc: 0.5833 - val_loss: 0.5728 - val_accuracy: 0.7392 - val_auc: 0.5532
# Epoch 29/41
# 1805/1805 [==============================] - 3s 2ms/step - loss: 0.5648 - accuracy: 0.7381 - auc: 0.5867 - val_loss: 0.5734 - val_accuracy: 0.7392 - val_auc: 0.5512
# Epoch 30/41
# 1805/1805 [==============================] - 3s 2ms/step - loss: 0.5642 - accuracy: 0.7381 - auc: 0.5887 - val_loss: 0.5716 - val_accuracy: 0.7392 - val_auc: 0.5447
# Epoch 31/41
# 1805/1805 [==============================] - 3s 2ms/step - loss: 0.5641 - accuracy: 0.7381 - auc: 0.5870 - val_loss: 0.5721 - val_accuracy: 0.7392 - val_auc: 0.5526
# Epoch 32/41
# 1805/1805 [==============================] - 3s 2ms/step - loss: 0.5639 - accuracy: 0.7381 - auc: 0.5896 - val_loss: 0.5746 - val_accuracy: 0.7392 - val_auc: 0.5485
# Epoch 33/41
# 1805/1805 [==============================] - 3s 2ms/step - loss: 0.5635 - accuracy: 0.7381 - auc: 0.5906 - val_loss: 0.5770 - val_accuracy: 0.7392 - val_auc: 0.5490
# Epoch 34/41
# 1805/1805 [==============================] - 3s 2ms/step - loss: 0.5633 - accuracy: 0.7381 - auc: 0.5916 - val_loss: 0.5716 - val_accuracy: 0.7392 - val_auc: 0.5493
# Epoch 35/41
# 1805/1805 [==============================] - 3s 2ms/step - loss: 0.5628 - accuracy: 0.7381 - auc: 0.5936 - val_loss: 0.5745 - val_accuracy: 0.7392 - val_auc: 0.5509
# Epoch 36/41
# 1805/1805 [==============================] - 3s 2ms/step - loss: 0.5625 - accuracy: 0.7381 - auc: 0.5948 - val_loss: 0.5736 - val_accuracy: 0.7392 - val_auc: 0.5524
# Epoch 37/41
# 1805/1805 [==============================] - 3s 2ms/step - loss: 0.5624 - accuracy: 0.7381 - auc: 0.5951 - val_loss: 0.5731 - val_accuracy: 0.7392 - val_auc: 0.5519
# Epoch 38/41
# 1805/1805 [==============================] - 3s 2ms/step - loss: 0.5621 - accuracy: 0.7381 - auc: 0.5954 - val_loss: 0.5749 - val_accuracy: 0.7392 - val_auc: 0.5553
# Epoch 39/41
# 1805/1805 [==============================] - 3s 2ms/step - loss: 0.5618 - accuracy: 0.7381 - auc: 0.5976 - val_loss: 0.5767 - val_accuracy: 0.7392 - val_auc: 0.5445
# Epoch 40/41
# 1805/1805 [==============================] - 3s 2ms/step - loss: 0.5614 - accuracy: 0.7381 - auc: 0.5991 - val_loss: 0.5746 - val_accuracy: 0.7392 - val_auc: 0.5535
# Epoch 41/41
# 1805/1805 [==============================] - 3s 2ms/step - loss: 0.5610 - accuracy: 0.7381 - auc: 0.6011 - val_loss: 0.5741 - val_accuracy: 0.7392 - val_auc: 0.5474

# %%
model.predict(X_test)
# Out:
# 201/201 [==============================] - 0s 791us/step
# array([[0.17203338],
#        [0.27950507],
#        [0.25978994],
#        ...,
#        [0.27261615],
#        [0.27357155],
#        [0.2950203 ]], dtype=float32)

# %%
fpr, tpr, thresholds= metrics.roc_curve(y_test, model.predict(X_test),pos_label=1)
# Out:
# 201/201 [==============================] - 0s 775us/step

# %%
auc = roc_auc_score(y_test,model.predict(X_test) )
plt.plot(fpr,tpr,label="home win, auc="+str(auc))
plt.legend(loc=4)
plt.show()
# Out:
# 201/201 [==============================] - 0s 796us/step

# %% [markdown]
# # Not relevant

# %% [markdown]
# ### Transform scores

# %%
data_to_test = X_test.copy()
data_to_test['draw_flag'] = y_test
data_to_test
# Out:
#        home_team_match_nr  home_team_goal_roll1_sum  home_team_goal_roll2_sum  \
# 41558                   7                         3                         5
# 3027                   23                         3                         5
# 8249                    7                         0                         2
# 16742                  15                         2                         3
# 39326                  21                         1                         4
# ...                   ...                       ...                       ...
# 42138                  23                         0                         2
# 53529                  40                         1                         5
# 45997                  33                         2                         4
# 50355                  23                         1                         2
# 50539                  16                         0                         0
#
#        home_team_goal_roll3_sum  home_team_goal_roll4_sum  \
# 41558                         6                         7
# 3027                          5                         5
# 8249                          2                         5
# 16742                         3                         4
# 39326                         5                         5
# ...                         ...                       ...
# 42138                         2                         3
# 53529                         5                         7
# 45997                         5                         9
# 50355                         4                         6
# 50539                         0                         3
#
#        home_team_opponents_goal_roll1_sum  home_team_opponents_goal_roll2_sum  \
# 41558                                   2                                   5
# 3027                                    1                                   2
# 8249                                    2                                   2
# 16742                                   1                                   1
# 39326                                   2                                   2
# ...                                   ...                                 ...
# 42138                                   1                                   1
# 53529                                   1                                   1
# 45997                                   2                                   2
# 50355                                   2                                   3
# 50539                                   0                                   1
#
#        home_team_opponents_goal_roll3_sum  home_team_opponents_goal_roll4_sum  \
# 41558                                   7                                   8
# 3027                                    3                                   4
# 8249                                    4                                   7
# 16742                                   2                                   2
# 39326                                   4                                   5
# ...                                   ...                                 ...
# 42138                                   2                                   3
# 53529                                   2                                   2
# 45997                                   3                                   5
# 50355                                   4                                   6
# 50539                                   4                                   4
#
#        home_team_shot_roll1_sum  ...  odds_away_team_defeat_roll2_mean  \
# 41558                        17  ...                             2.500
# 3027                         13  ...                             2.250
# 8249                          8  ...                             2.250
# 16742                         7  ...                             4.200
# 39326                         9  ...                             3.395
# ...                         ...  ...                               ...
# 42138                         7  ...                             3.050
# 53529                        15  ...                             2.575
# 45997                        14  ...                             9.230
# 50355                        22  ...                             2.415
# 50539                         9  ...                             3.150
#
#        odds_away_team_defeat_roll3_mean  odds_away_team_defeat_roll4_mean  \
# 41558                             2.250                             2.162
# 3027                              3.500                             3.188
# 8249                              2.110                             2.358
# 16742                             4.467                             4.350
# 39326                             3.060                             2.710
# ...                                 ...                               ...
# 42138                             3.100                             3.408
# 53529                             2.837                             2.650
# 45997                             8.713                             8.660
# 50355                             2.290                             2.202
# 50539                             3.750                             3.575
#
#        away_team_point_mean  away_team_expected_point_mean  home_win_prob  \
# 41558                 1.333                          0.000       0.555556
# 3027                  1.300                          1.500       0.571429
# 8249                  0.333                          0.000       0.476190
# 16742                 1.571                          3.000       0.380228
# 39326                 0.400                          0.000       0.571429
# ...                     ...                            ...            ...
# 42138                 1.083                          2.500       0.230947
# 53529                 1.368                          0.316       0.543478
# 45997                 1.875                          2.812       0.431034
# 50355                 0.100                          0.000       0.606061
# 50539                 1.625                          1.500       0.305810
#
#        draw_prob  away_win_prob  delta_prob  draw_flag
# 41558   0.263158       0.210526    0.345029          0
# 3027    0.312500       0.181818    0.389610          0
# 8249    0.303030       0.285714    0.190476          0
# 16742   0.307692       0.380228    0.000000          0
# 39326   0.285714       0.210526    0.360902          0
# ...          ...            ...         ...        ...
# 42138   0.285714       0.540541   -0.309594          0
# 53529   0.290698       0.229885    0.313593          0
# 45997   0.272480       0.344828    0.086207          0
# 50355   0.258398       0.184162    0.421899          0
# 50539   0.310559       0.432900   -0.127090          1
#
# [6416 rows x 163 columns]

# %%
x = model.predict(X_test).reshape(-1, 1)

x_norm = pre.MinMaxScaler().fit_transform(x)
pred_alter = 1-x_norm
data_to_test['pred_alt'] = pred_alter
# Out:
# 201/201 [==============================] - 0s 819us/step

# %%
maxi = 0
maxi_list = []

for i in range(0,99):
    
    for x in range(0,99):

        data_to_test["pred_w_odds"] =  np.where((data_to_test["draw_prob"] > i/100) &
                                                (data_to_test["pred_alt"] >= x/100),
                                                (data_to_test["draw_prob"] + data_to_test["pred_alt"])/2,
                                                np.where((data_to_test["draw_prob"] > i/100) &
                                                         (data_to_test["pred_alt"] < x/100),
                                                          data_to_test["draw_prob"],
                                                          data_to_test["pred_alt"]
                                                ))
    
        acc = sum(data_to_test["draw_flag"] == (data_to_test["pred_w_odds"] > 0.5).astype(int)) / len(data_to_test)
        
        if acc > maxi:
            maxi = acc
            maxi_list = []
            maxi_list.append(i)
            maxi_list.append(x)
            maxi_list.append(acc)

# %%
auc = roc_auc_score(data_to_test['draw_flag'],data_to_test['pred_w_odds'])
plt.plot(fpr,tpr,label="draw, auc="+str(auc))
plt.legend(loc=4)
plt.show()

# %%
maxi
# Out:
# 0.7392456359102244

# %%
maxi_list
# Out:
# [0, 97, 0.7392456359102244]

# %%
i = 0
x = 97

data_to_test["pred_w_odds"] =  np.where((data_to_test["draw_prob"] > i/100) &
                                        (data_to_test["pred_alt"] >= x/100),
                                        (data_to_test["draw_prob"] + data_to_test["pred_alt"])/2,
                                        np.where((data_to_test["draw_prob"] > i/100) &
                                                 (data_to_test["pred_alt"] < x/100),
                                                  data_to_test["draw_prob"],
                                                  data_to_test["pred_alt"]))

# %%
auc = roc_auc_score(data_to_test['draw_flag'],data_to_test['pred_w_odds'])
plt.plot(fpr,tpr,label="draw , auc="+str(auc))
plt.legend(loc=4)
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
 
mat = confusion_matrix(data_to_test["draw_flag"], data_to_test["draw_prob"] > 0.5)
labels = ['0', '1']
 
sns.heatmap(mat, square=True, annot=True, fmt='d', cbar=False, cmap='Blues',
            xticklabels=labels, yticklabels=labels)
 
plt.xlabel('Pred')
plt.ylabel('Actual')
# Out:
# Text(91.68, 0.5, 'Actual')

# %% [markdown]
# ### Plots

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()
 
acc = hist.history['accuracy']
val = hist.history['val_accuracy']
epochs = range(1, len(acc) + 1)
 
plt.plot(epochs, acc, '-', label='Training accuracy')
plt.plot(epochs, val, ':', label='Validation accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.plot()
# Out:
# []

# %%
y_predicted = model.predict(X_test) > 0.5
mat = confusion_matrix(y_test, y_predicted)
labels = ['0', '1']
 
sns.heatmap(mat, square=True, annot=True, fmt='d', cbar=False, cmap='Blues',
            xticklabels=labels, yticklabels=labels)
 
plt.xlabel('Pred')
plt.ylabel('Actual')
# Out:
# 201/201 [==============================] - 0s 788us/step
# Text(89.18, 0.5, 'Actual')

# %%
fpr, tpr, thresholds= metrics.roc_curve(y_test, model.predict(X_test),pos_label=1)
# Out:
# 201/201 [==============================] - 0s 839us/step

# %%
metrics.auc(fpr, tpr)
# Out:
# 0.5398312472062203
